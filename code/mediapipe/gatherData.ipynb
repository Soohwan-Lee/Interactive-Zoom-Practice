# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detection

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <img src="https://i.imgur.com/8bForKY.png">
# <img src="https://i.imgur.com/AzKNp7A.png">

# %%
import csv
import os
import numpy as np
import time

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Background"

# %%
start = False
max_time_end = time.time()
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image = cv2.flip(image, 1)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        if start:
            # Export coordinates
            try:
                # Extract Pose landmarks
                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                # Extract Face landmarks
                face = results.face_landmarks.landmark
                face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

                # Concate rows
                row = pose_row+face_row

                # Append class name 
                row.insert(0, class_name)

                # Export to CSV
                with open('coords.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(row)

            except:
                pass
                        
        cv2.imshow('Raw Webcam Feed', image)
        
        # r키를 눌러서 녹화 시작 - 20초간 녹화
        if cv2.waitKey(10) & 0xFF == ord('r'):
            print("Recording Start!")
            max_time_end = time.time() + (20)
            start = True
        
        # r키를 눌러서 녹화 시작 후 15초 후에 녹화 종료
        if time.time() > max_time_end and start == True:
            start = False
            break
        
        # q키를 눌러서 강제로 녹화 종료 가능
        if cv2.waitKey(10) & 0xFF == ord('q'):
            start = False
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Recording Start!

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0  Question  0.548189  0.552062 -1.224939  0.999919  0.577016  0.469688
# 1  Question  0.548275  0.552074 -1.231062  0.999924  0.577009  0.469733
# 2  Question  0.548318  0.552050 -1.200374  0.999929  0.576998  0.469761
# 3  Question  0.548292  0.551852 -1.179757  0.999933  0.576821  0.469684
# 4  Question  0.547916  0.551791 -1.212180  0.999936  0.576482  0.469669
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -1.157368  0.999749  0.595135  ... -0.009109   0.0  0.609377  0.476348
# 1 -1.163646  0.999758  0.595120  ... -0.009214   0.0  0.608569  0.477902
# 2 -1.131535  0.999769  0.595105  ... -0.009360   0.0  0.608658  0.477106
# 3 -1.112442  0.999779  0.594808  ... -0.009254   0.0  0.608440  0.476667
# 4 -1.142909  0.999783  0.594499  ... -0.009415   0.0  0.607961  0.474828
#
#        z500  v500      x501      y501      z501  v501
# 0  0.006812   0.0  0.613769  0.470762  0.006875   0.0
# 1  0.006326   0.0  0.613073  0.472141  0.006374   0.0
# 2  0.006191   0.0  0.613126  0.471116  0.006262   0.0
# 3  0.006188   0.0  0.612909  0.470686  0.006251   0.0
# 4  0.005927   0.0  0.612369  0.469289  0.005945   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#            class        x1        y1        z1        v1        x2        y2  \
# 1154  Background  0.526909  0.563997 -0.990643  0.999610  0.559038  0.476908
# 1155  Background  0.525182  0.563259 -1.092317  0.999625  0.555318  0.476035
# 1156  Background  0.524957  0.563254 -1.083246  0.999633  0.554133  0.475842
# 1157  Background  0.525607  0.562815 -1.050233  0.999646  0.554047  0.475582
# 1158  Background  0.525107  0.562902 -1.078489  0.999646  0.551505  0.475573
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# 1154 -0.962471  0.999439  0.579628  ... -0.009631   0.0  0.598657  0.473012
# 1155 -1.055096  0.999462  0.575551  ... -0.009642   0.0  0.595469  0.472069
# 1156 -1.047405  0.999473  0.574252  ... -0.008720   0.0  0.593861  0.469415
# 1157 -1.002611  0.999487  0.573995  ... -0.009631   0.0  0.586881  0.470051
# 1158 -1.020686  0.999492  0.570883  ... -0.009130   0.0  0.581675  0.470541
#
#           z500  v500      x501      y501      z501  v501
# 1154  0.001568   0.0  0.603442  0.466627  0.001291   0.0
# 1155  0.002910   0.0  0.600041  0.466492  0.002717   0.0
# 1156  0.005087   0.0  0.598315  0.463913  0.004970   0.0
# 1157  0.004264   0.0  0.591369  0.464321  0.004185   0.0
# 1158  0.006061   0.0  0.586056  0.464831  0.006122   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='Background']
# Out:
#            class        x1        y1        z1        v1        x2        y2  \
# 859   Background  0.517403  0.556493 -1.096508  0.999794  0.538856  0.465316
# 860   Background  0.517015  0.556290 -1.070512  0.999797  0.538578  0.465331
# 861   Background  0.516991  0.556253 -1.067021  0.999804  0.538567  0.465504
# 862   Background  0.516928  0.556216 -1.088615  0.999801  0.538525  0.465488
# 863   Background  0.516914  0.556178 -1.114611  0.999803  0.538506  0.465537
# ...          ...       ...       ...       ...       ...       ...       ...
# 1154  Background  0.526909  0.563997 -0.990643  0.999610  0.559038  0.476908
# 1155  Background  0.525182  0.563259 -1.092317  0.999625  0.555318  0.476035
# 1156  Background  0.524957  0.563254 -1.083246  0.999633  0.554133  0.475842
# 1157  Background  0.525607  0.562815 -1.050233  0.999646  0.554047  0.475582
# 1158  Background  0.525107  0.562902 -1.078489  0.999646  0.551505  0.475573
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# 859  -1.064797  0.999655  0.555972  ... -0.008624   0.0  0.573551  0.463094
# 860  -1.039678  0.999658  0.555814  ... -0.008437   0.0  0.573856  0.462517
# 861  -1.035447  0.999667  0.555797  ... -0.008648   0.0  0.573939  0.462496
# 862  -1.053585  0.999666  0.555770  ... -0.007995   0.0  0.574408  0.461211
# 863  -1.076825  0.999668  0.555753  ... -0.007763   0.0  0.573998  0.460321
# ...        ...       ...       ...  ...       ...   ...       ...       ...
# 1154 -0.962471  0.999439  0.579628  ... -0.009631   0.0  0.598657  0.473012
# 1155 -1.055096  0.999462  0.575551  ... -0.009642   0.0  0.595469  0.472069
# 1156 -1.047405  0.999473  0.574252  ... -0.008720   0.0  0.593861  0.469415
# 1157 -1.002611  0.999487  0.573995  ... -0.009631   0.0  0.586881  0.470051
# 1158 -1.020686  0.999492  0.570883  ... -0.009130   0.0  0.581675  0.470541
#
#           z500  v500      x501      y501      z501  v501
# 859   0.008130   0.0  0.577504  0.457355  0.008316   0.0
# 860   0.008215   0.0  0.577812  0.456511  0.008406   0.0
# 861   0.008343   0.0  0.577897  0.456693  0.008550   0.0
# 862   0.009027   0.0  0.578374  0.455653  0.009210   0.0
# 863   0.009604   0.0  0.577965  0.454989  0.009790   0.0
# ...        ...   ...       ...       ...       ...   ...
# 1154  0.001568   0.0  0.603442  0.466627  0.001291   0.0
# 1155  0.002910   0.0  0.600041  0.466492  0.002717   0.0
# 1156  0.005087   0.0  0.598315  0.463913  0.004970   0.0
# 1157  0.004264   0.0  0.591369  0.464321  0.004185   0.0
# 1158  0.006061   0.0  0.586056  0.464831  0.006122   0.0
#
# [300 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\LeeSooHwan\anaconda3\envs\py37\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Smile', 'Background', 'Smile', 'Background', 'Smile', 'Smile',
#        'Background', 'Smile', 'ThumbUp', 'ThumbUp', 'Question',
#        'Background', 'Background', 'ThumbUp', 'Background', 'ThumbUp',
#        'Smile', 'ThumbUp', 'Background', 'Background', 'Smile', 'Smile',
#        'Background', 'Background', 'Question', 'Background', 'Background',
#        'ThumbUp', 'Background', 'Smile', 'ThumbUp', 'ThumbUp',
#        'Background', 'Question', 'Background', 'Smile', 'Smile',
#        'Question', 'ThumbUp', 'Question', 'Background', 'Smile',
#        'Background', 'Smile', 'Smile', 'ThumbUp', 'Background', 'ThumbUp',
#        'Background', 'Background', 'Question', 'Smile', 'ThumbUp',
#        'Background', 'Question', 'Smile', 'ThumbUp', 'ThumbUp',
#        'Background', 'Background', 'Background', 'Smile', 'Smile',
#        'Question', 'Smile', 'Smile', 'Question', 'Question', 'Background',
#        'Background', 'Smile', 'Background', 'Background', 'Question',
#        'Question', 'Background', 'ThumbUp', 'ThumbUp', 'Smile',
#        'Background', 'Background', 'Background', 'ThumbUp', 'Background',
#        'Question', 'Question', 'Background', 'Smile', 'Background',
#        'ThumbUp', 'ThumbUp', 'Background', 'Smile', 'Question', 'Smile',
#        'Question', 'Question', 'Background', 'Background', 'Question',
#        'ThumbUp', 'Question', 'Question', 'Background', 'Smile',
#        'ThumbUp', 'ThumbUp', 'ThumbUp', 'Background', 'Question',
#        'Background', 'Background', 'Question', 'ThumbUp', 'Smile',
#        'Smile', 'ThumbUp', 'ThumbUp', 'Question', 'Question', 'Question',
#        'ThumbUp', 'Background', 'Question', 'ThumbUp', 'Question',
#        'Smile', 'Question', 'Smile', 'Question', 'Smile', 'ThumbUp',
#        'ThumbUp', 'Background', 'Background', 'Smile', 'ThumbUp',
#        'Question', 'Smile', 'Background', 'Question', 'ThumbUp',
#        'Background', 'ThumbUp', 'ThumbUp', 'Question', 'Background',
#        'ThumbUp', 'ThumbUp', 'Smile', 'Smile', 'Background', 'Question',
#        'Question', 'Smile', 'Question', 'Smile', 'Question', 'Smile',
#        'Smile', 'Background', 'Smile', 'Smile', 'Question', 'Question',
#        'Background', 'Smile', 'ThumbUp', 'Question', 'Smile',
#        'Background', 'Question', 'Background', 'ThumbUp', 'Question',
#        'Question', 'Background', 'Smile', 'ThumbUp', 'Background',
#        'Smile', 'Smile', 'Question', 'ThumbUp', 'Question', 'Smile',
#        'Smile', 'Smile', 'ThumbUp', 'Question', 'ThumbUp', 'Question',
#        'Smile', 'Background', 'Background', 'ThumbUp', 'ThumbUp', 'Smile',
#        'ThumbUp', 'ThumbUp', 'Background', 'Question', 'Smile', 'Smile',
#        'ThumbUp', 'Smile', 'ThumbUp', 'Question', 'ThumbUp', 'Background',
#        'ThumbUp', 'Question', 'Question', 'Smile', 'ThumbUp', 'ThumbUp',
#        'Smile', 'Question', 'Smile', 'Smile', 'Smile', 'Smile', 'Smile',
#        'Question', 'Question', 'ThumbUp', 'ThumbUp', 'Smile', 'Question',
#        'ThumbUp', 'ThumbUp', 'ThumbUp', 'Smile', 'Smile', 'ThumbUp',
#        'Background', 'Smile', 'Background', 'Question', 'Question',
#        'Background', 'Smile', 'Background', 'Question', 'Question',
#        'ThumbUp', 'ThumbUp', 'Question', 'Question', 'Background',
#        'Smile', 'Background', 'Background', 'ThumbUp', 'Smile', 'ThumbUp',
#        'Smile', 'Background', 'Smile', 'Smile', 'Question', 'Background',
#        'Question', 'Background', 'Background', 'Background', 'Smile',
#        'Question', 'ThumbUp', 'ThumbUp', 'Smile', 'Background',
#        'Question', 'Background', 'Background', 'Background', 'Smile',
#        'Smile', 'Background', 'Background', 'ThumbUp', 'ThumbUp',
#        'ThumbUp', 'Question', 'ThumbUp', 'Background', 'Background',
#        'Smile', 'ThumbUp', 'Question', 'Background', 'Smile', 'ThumbUp',
#        'Question', 'Background', 'ThumbUp', 'Background', 'ThumbUp',
#        'Background', 'Background', 'Background', 'Background', 'ThumbUp',
#        'Question', 'Question', 'ThumbUp', 'Smile', 'Question',
#        'Background', 'Question', 'ThumbUp', 'ThumbUp', 'Smile', 'ThumbUp',
#        'Question', 'Question', 'Background', 'ThumbUp', 'ThumbUp',
#        'Question', 'Smile', 'Background', 'Smile', 'Background', 'Smile',
#        'Question', 'Question', 'Question', 'Question', 'Question',
#        'Smile', 'Question', 'Background', 'Background', 'Smile',
#        'Background', 'Smile', 'ThumbUp', 'Question', 'Smile', 'ThumbUp',
#        'ThumbUp', 'ThumbUp', 'Background', 'Smile', 'ThumbUp', 'Question',
#        'ThumbUp'], dtype='<U10')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9913793103448276

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Smile', 'Background', 'Smile', 'Background', 'Smile', 'Smile',
#        'Background', 'Smile', 'ThumbUp', 'ThumbUp', 'Question',
#        'Background', 'Background', 'ThumbUp', 'Background', 'ThumbUp',
#        'Smile', 'ThumbUp', 'Background', 'Background', 'Smile', 'Smile',
#        'Background', 'Background', 'Question', 'Background', 'Background',
#        'ThumbUp', 'Background', 'Smile', 'ThumbUp', 'ThumbUp',
#        'Background', 'Question', 'Background', 'Smile', 'Smile',
#        'Question', 'ThumbUp', 'Question', 'Background', 'Smile',
#        'Background', 'Smile', 'Smile', 'ThumbUp', 'Background', 'ThumbUp',
#        'Background', 'Background', 'Question', 'Smile', 'ThumbUp',
#        'Background', 'Question', 'Smile', 'ThumbUp', 'ThumbUp',
#        'Background', 'Background', 'Background', 'Smile', 'Smile',
#        'Question', 'Smile', 'Smile', 'Question', 'Question', 'Background',
#        'Background', 'Smile', 'Background', 'Background', 'Question',
#        'Question', 'Background', 'ThumbUp', 'ThumbUp', 'Smile',
#        'Background', 'Background', 'Background', 'ThumbUp', 'Background',
#        'Question', 'Question', 'Background', 'Smile', 'Background',
#        'ThumbUp', 'ThumbUp', 'Background', 'Smile', 'Question', 'Smile',
#        'Question', 'Question', 'Background', 'Background', 'Question',
#        'ThumbUp', 'Question', 'Question', 'Background', 'Smile',
#        'ThumbUp', 'ThumbUp', 'ThumbUp', 'Background', 'Question',
#        'Background', 'Background', 'Question', 'ThumbUp', 'Smile',
#        'Smile', 'ThumbUp', 'ThumbUp', 'Question', 'Question', 'Question',
#        'ThumbUp', 'Background', 'Question', 'ThumbUp', 'Question',
#        'Smile', 'Question', 'Smile', 'Question', 'Smile', 'ThumbUp',
#        'ThumbUp', 'Background', 'Background', 'Smile', 'ThumbUp',
#        'Question', 'Smile', 'Background', 'Question', 'ThumbUp',
#        'Background', 'ThumbUp', 'ThumbUp', 'Question', 'Background',
#        'ThumbUp', 'ThumbUp', 'Smile', 'Smile', 'Background', 'Question',
#        'Question', 'Smile', 'Question', 'Smile', 'Question', 'Smile',
#        'Smile', 'Background', 'Smile', 'Smile', 'Question', 'Question',
#        'Background', 'Smile', 'ThumbUp', 'Question', 'Smile',
#        'Background', 'Question', 'Background', 'ThumbUp', 'Question',
#        'Question', 'Background', 'Smile', 'ThumbUp', 'Background',
#        'Smile', 'Smile', 'Question', 'ThumbUp', 'Question', 'Smile',
#        'Smile', 'Smile', 'ThumbUp', 'Question', 'ThumbUp', 'Question',
#        'Smile', 'Background', 'Background', 'ThumbUp', 'ThumbUp', 'Smile',
#        'ThumbUp', 'ThumbUp', 'Background', 'Question', 'Smile', 'Smile',
#        'ThumbUp', 'Smile', 'ThumbUp', 'Question', 'ThumbUp', 'Background',
#        'ThumbUp', 'Question', 'Question', 'Smile', 'ThumbUp', 'ThumbUp',
#        'Smile', 'Question', 'Smile', 'Smile', 'Smile', 'Smile', 'Smile',
#        'Question', 'Question', 'ThumbUp', 'ThumbUp', 'Smile', 'Question',
#        'ThumbUp', 'ThumbUp', 'ThumbUp', 'Smile', 'Smile', 'ThumbUp',
#        'Background', 'Smile', 'Background', 'Question', 'Question',
#        'Background', 'Smile', 'Background', 'Question', 'Question',
#        'ThumbUp', 'ThumbUp', 'Question', 'Question', 'Background',
#        'Smile', 'Background', 'Background', 'ThumbUp', 'Smile', 'ThumbUp',
#        'Smile', 'Background', 'Smile', 'Smile', 'Question', 'Background',
#        'Question', 'Background', 'Background', 'Background', 'Smile',
#        'Question', 'ThumbUp', 'ThumbUp', 'Smile', 'Background',
#        'Question', 'Background', 'Background', 'Background', 'Smile',
#        'Smile', 'Background', 'Background', 'ThumbUp', 'ThumbUp',
#        'ThumbUp', 'Question', 'ThumbUp', 'Background', 'Background',
#        'Smile', 'ThumbUp', 'Question', 'Background', 'Smile', 'ThumbUp',
#        'Question', 'Background', 'ThumbUp', 'Background', 'ThumbUp',
#        'Background', 'Background', 'Background', 'Background', 'ThumbUp',
#        'Question', 'Question', 'ThumbUp', 'Smile', 'Question',
#        'Background', 'Question', 'ThumbUp', 'ThumbUp', 'Smile', 'ThumbUp',
#        'Question', 'Question', 'Background', 'ThumbUp', 'ThumbUp',
#        'Question', 'Smile', 'Background', 'Smile', 'Background', 'Smile',
#        'Question', 'Question', 'Question', 'Question', 'Question',
#        'Smile', 'Question', 'Background', 'Background', 'Smile',
#        'Background', 'Smile', 'ThumbUp', 'Question', 'Smile', 'ThumbUp',
#        'ThumbUp', 'ThumbUp', 'Background', 'Smile', 'ThumbUp', 'Question',
#        'ThumbUp'], dtype=object)

# %%
y_test
# Out:
# 805          Smile
# 1049    Background
# 780          Smile
# 928     Background
# 706          Smile
#            ...
# 906     Background
# 652          Smile
# 415        ThumbUp
# 214       Question
# 351        ThumbUp
# Name: class, Length: 348, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # Test DEMO

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image = cv2.flip(image, 1)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Smile [0.21 0.03 0.41 0.35]
# ThumbUp [0.4  0.04 0.13 0.43]
# Background [0.42 0.04 0.12 0.42]
# Background [0.46 0.07 0.06 0.41]
# Background [0.48 0.14 0.03 0.35]
# Background [0.6  0.13 0.02 0.25]
# Background [0.69 0.06 0.02 0.23]
# Background [0.69 0.07 0.01 0.23]
# Background [0.69 0.07 0.01 0.23]
# Background [0.71 0.07 0.02 0.2 ]
# Background [0.67 0.07 0.02 0.24]
# Background [0.68 0.06 0.02 0.24]
# Background [0.68 0.06 0.02 0.24]
# Background [0.68 0.06 0.02 0.24]
# Background [0.69 0.06 0.02 0.23]
# Background [0.66 0.1  0.01 0.23]
# Background [0.64 0.11 0.01 0.24]
# Background [0.67 0.1  0.01 0.22]
# Background [0.62 0.1  0.01 0.27]
# Background [0.61 0.11 0.01 0.27]
# Background [0.62 0.1  0.01 0.27]
# Background [0.63 0.1  0.01 0.26]
# Background [0.63 0.11 0.01 0.25]
# Background [0.63 0.11 0.01 0.25]
# Background [0.64 0.11 0.01 0.24]
# Background [0.63 0.1  0.01 0.26]
# Background [0.63 0.1  0.01 0.26]
# Background [0.66 0.1  0.01 0.23]
# Background [0.7  0.06 0.01 0.23]
# Background [0.7  0.06 0.01 0.23]
# Background [0.36 0.34 0.01 0.29]
# Question [0.22 0.43 0.02 0.33]
# Question [0.14 0.6  0.02 0.24]
# Question [0.15 0.51 0.02 0.32]
# Question [0.14 0.52 0.02 0.32]
# Question [0.09 0.48 0.02 0.41]
# Question [0.04 0.54 0.02 0.4 ]
# Question [0.02 0.56 0.   0.42]
# Question [0.02 0.59 0.   0.39]
# Question [0.02 0.53 0.01 0.44]
# Question [0.02 0.54 0.01 0.43]
# ThumbUp [0.02 0.41 0.01 0.56]
# ThumbUp [0.02 0.25 0.   0.73]
# ThumbUp [0.02 0.24 0.01 0.73]
# ThumbUp [0.02 0.23 0.01 0.74]
# ThumbUp [0.02 0.23 0.01 0.74]
# ThumbUp [0.02 0.2  0.01 0.77]
# ThumbUp [0.03 0.18 0.01 0.78]
# ThumbUp [0.03 0.18 0.01 0.78]
# ThumbUp [0.03 0.2  0.01 0.76]
# ThumbUp [0.01 0.2  0.01 0.78]
# ThumbUp [0.02 0.23 0.01 0.74]
# ThumbUp [0.01 0.19 0.01 0.79]
# ThumbUp [0.02 0.22 0.01 0.75]
# ThumbUp [0.02 0.19 0.01 0.78]
# ThumbUp [0.3  0.18 0.01 0.51]
# ThumbUp [0.35 0.19 0.01 0.45]
# Smile [0.2  0.12 0.6  0.08]
# Smile [0.03 0.04 0.91 0.02]
# Smile [0.   0.02 0.97 0.01]
# Smile [0.03 0.03 0.92 0.02]
# Smile [0. 0. 1. 0.]
# Smile [0.08 0.01 0.91 0.  ]
# Background [0.48 0.09 0.02 0.41]
# Background [0.49 0.13 0.02 0.36]
# Background [0.47 0.13 0.02 0.38]
# Background [0.47 0.13 0.02 0.38]
# Background [0.49 0.14 0.02 0.35]
# Background [0.49 0.12 0.02 0.37]
# Background [0.49 0.11 0.02 0.38]
# Background [0.53 0.11 0.02 0.34]
# Background [0.53 0.07 0.05 0.35]
# Smile [0.39 0.04 0.46 0.11]
# Smile [0.22 0.03 0.71 0.04]
# Smile [0.02 0.02 0.96 0.  ]
# Smile [0.02 0.01 0.97 0.  ]
# Smile [0.02 0.01 0.97 0.  ]
# Smile [0.02 0.01 0.97 0.  ]
# Smile [0.   0.04 0.96 0.  ]
# Smile [0.07 0.05 0.88 0.  ]
# Smile [0.06 0.09 0.85 0.  ]
# Smile [0.08 0.11 0.81 0.  ]
# Background [0.42 0.25 0.05 0.28]
# Background [0.46 0.27 0.02 0.25]
# Background [0.48 0.26 0.02 0.24]
# Background [0.5  0.25 0.02 0.23]
# Background [0.49 0.26 0.02 0.23]
# Background [0.48 0.28 0.02 0.22]
# Background [0.44 0.29 0.02 0.25]
# Background [0.44 0.28 0.02 0.26]
# Background [0.5  0.28 0.02 0.2 ]
# Background [0.5  0.27 0.02 0.21]
# Background [0.54 0.19 0.02 0.25]
# Background [0.56 0.19 0.03 0.22]
# Background [0.64 0.14 0.03 0.19]
# Background [0.65 0.14 0.03 0.18]
# Background [0.59 0.15 0.03 0.23]
# Background [0.58 0.13 0.03 0.26]
# Background [0.67 0.06 0.03 0.24]
# Background [0.69 0.05 0.03 0.23]
# Background [0.59 0.09 0.03 0.29]
# Background [0.54 0.1  0.03 0.33]
# Background [0.49 0.08 0.03 0.4 ]
# Background [0.52 0.12 0.03 0.33]
# Background [0.55 0.1  0.03 0.32]
# Background [0.48 0.14 0.03 0.35]
# Background [0.48 0.11 0.03 0.38]
# Background [0.47 0.14 0.03 0.36]
# Background [0.51 0.16 0.03 0.3 ]
# Background [0.54 0.14 0.03 0.29]
# Background [0.52 0.2  0.02 0.26]
# Background [0.52 0.15 0.02 0.31]
# Background [0.52 0.14 0.02 0.32]
# Background [0.54 0.15 0.02 0.29]
# Background [0.5  0.14 0.01 0.35]
# Background [0.5  0.15 0.01 0.34]
# Background [0.5  0.16 0.01 0.33]
# Background [0.5  0.12 0.01 0.37]
# Background [0.5  0.12 0.01 0.37]
# Background [0.52 0.1  0.01 0.37]
# Background [0.62 0.11 0.01 0.26]
# Background [0.62 0.11 0.02 0.25]
# Question [0.22 0.45 0.02 0.31]
# Question [0.18 0.57 0.01 0.24]
# Question [0.16 0.62 0.01 0.21]
# Question [0.14 0.62 0.02 0.22]
# Question [0.13 0.69 0.02 0.16]
# Question [0.08 0.73 0.02 0.17]
# Question [0.04 0.77 0.02 0.17]
# Question [0.04 0.79 0.01 0.16]
# Question [0.04 0.79 0.01 0.16]
# Question [0.04 0.76 0.   0.2 ]
# Question [0.03 0.78 0.01 0.18]
# Question [0.03 0.76 0.01 0.2 ]
# Question [0.02 0.78 0.01 0.19]
# Question [0.02 0.77 0.01 0.2 ]
# Question [0.02 0.8  0.01 0.17]
# Question [0.01 0.8  0.01 0.18]
# Question [0.01 0.81 0.01 0.17]
# Question [0.   0.82 0.02 0.16]
# Question [0.   0.85 0.01 0.14]
# Question [0.   0.82 0.02 0.16]
# Question [0.   0.82 0.01 0.17]
# Question [0.   0.78 0.02 0.2 ]
# Question [0.   0.78 0.01 0.21]
# Question [0.   0.82 0.01 0.17]
# Question [0.   0.8  0.01 0.19]
# Question [0.   0.83 0.01 0.16]
# Question [0.   0.83 0.01 0.16]
# Question [0.   0.79 0.01 0.2 ]
# Question [0.   0.74 0.   0.26]
# Question [0.   0.72 0.01 0.27]
# Question [0.   0.69 0.01 0.3 ]
# Question [0.   0.74 0.01 0.25]
# Question [0.   0.72 0.02 0.26]
# Question [0.   0.73 0.01 0.26]
# Question [0.   0.73 0.01 0.26]
# Question [0.   0.74 0.01 0.25]
# Question [0.   0.72 0.01 0.27]
# Question [0.   0.68 0.   0.32]
# Question [0.   0.69 0.01 0.3 ]
# Question [0.   0.7  0.01 0.29]
# Question [0.   0.7  0.01 0.29]
# Question [0.   0.69 0.01 0.3 ]
# Question [0.   0.69 0.01 0.3 ]
# Question [0.   0.66 0.01 0.33]
# Question [0.   0.65 0.01 0.34]
# Question [0.   0.63 0.01 0.36]
# Question [0.   0.59 0.01 0.4 ]
# Question [0.   0.53 0.01 0.46]
# Question [0.   0.51 0.01 0.48]
# Question [0.01 0.52 0.01 0.46]
# Question [0.01 0.57 0.01 0.41]
# Question [0.01 0.53 0.01 0.45]
# Question [0.01 0.54 0.01 0.44]
# Question [0.01 0.51 0.01 0.47]
# Question [0.   0.5  0.01 0.49]
# ThumbUp [0.   0.48 0.01 0.51]
# ThumbUp [0.   0.47 0.01 0.52]
# ThumbUp [0.   0.46 0.01 0.53]
# ThumbUp [0.   0.47 0.01 0.52]
# ThumbUp [0.   0.45 0.01 0.54]
# ThumbUp [0.   0.45 0.01 0.54]
# ThumbUp [0.   0.47 0.01 0.52]
# ThumbUp [0.   0.47 0.01 0.52]
# ThumbUp [0.   0.47 0.02 0.51]
# ThumbUp [0.   0.47 0.01 0.52]
# ThumbUp [0.   0.48 0.01 0.51]
# Question [0.   0.51 0.01 0.48]
# Question [0.   0.51 0.01 0.48]
# Question [0.   0.51 0.01 0.48]
# Question [0.   0.52 0.01 0.47]
# Question [0.   0.51 0.01 0.48]
# ThumbUp [0.   0.43 0.01 0.56]
# ThumbUp [0.   0.39 0.01 0.6 ]
# ThumbUp [0.   0.36 0.01 0.63]
# ThumbUp [0.   0.38 0.01 0.61]
# ThumbUp [0.   0.42 0.01 0.57]
# ThumbUp [0.   0.43 0.01 0.56]
# ThumbUp [0.01 0.41 0.01 0.57]
# ThumbUp [0.01 0.41 0.   0.58]
# ThumbUp [0.   0.39 0.01 0.6 ]
# ThumbUp [0.   0.43 0.01 0.56]
# ThumbUp [0.   0.42 0.01 0.57]
# ThumbUp [0.   0.43 0.   0.57]
# ThumbUp [0.   0.45 0.01 0.54]
# ThumbUp [0.01 0.43 0.01 0.55]
# ThumbUp [0.01 0.44 0.01 0.54]
# Question [0.02 0.59 0.   0.39]
# Question [0.1  0.57 0.   0.33]
# Question [0.18 0.46 0.   0.36]
# ThumbUp [0.16 0.38 0.   0.46]
# ThumbUp [0.11 0.36 0.02 0.51]
# ThumbUp [0.11 0.33 0.02 0.54]
# ThumbUp [0.19 0.35 0.02 0.44]
# ThumbUp [0.23 0.33 0.05 0.39]
# ThumbUp [0.23 0.33 0.05 0.39]
# ThumbUp [0.22 0.33 0.06 0.39]
# ThumbUp [0.21 0.32 0.06 0.41]
# ThumbUp [0.21 0.31 0.05 0.43]
# ThumbUp [0.21 0.33 0.02 0.44]
# ThumbUp [0.21 0.31 0.04 0.44]
# ThumbUp [0.22 0.33 0.02 0.43]
# ThumbUp [0.22 0.33 0.02 0.43]
# ThumbUp [0.21 0.32 0.03 0.44]
# ThumbUp [0.22 0.33 0.02 0.43]
# ThumbUp [0.19 0.31 0.04 0.46]
# ThumbUp [0.2  0.34 0.05 0.41]
# ThumbUp [0.2  0.36 0.06 0.38]
# ThumbUp [0.2  0.36 0.06 0.38]
# ThumbUp [0.2  0.36 0.06 0.38]
# ThumbUp [0.2  0.36 0.06 0.38]
# ThumbUp [0.2  0.36 0.05 0.39]
# ThumbUp [0.2  0.38 0.02 0.4 ]
# ThumbUp [0.2  0.36 0.05 0.39]
# ThumbUp [0.2  0.36 0.06 0.38]
# ThumbUp [0.23 0.21 0.04 0.52]
# ThumbUp [0.23 0.21 0.06 0.5 ]
# ThumbUp [0.23 0.2  0.04 0.53]
# ThumbUp [0.23 0.19 0.06 0.52]
# ThumbUp [0.23 0.19 0.06 0.52]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.24 0.18 0.06 0.52]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.05 0.54]
# ThumbUp [0.23 0.18 0.04 0.55]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.05 0.54]
# ThumbUp [0.23 0.18 0.05 0.54]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.06 0.53]
# ThumbUp [0.23 0.18 0.05 0.54]
# ThumbUp [0.24 0.17 0.06 0.53]
# ThumbUp [0.24 0.17 0.06 0.53]
# ThumbUp [0.24 0.2  0.06 0.5 ]
# ThumbUp [0.22 0.29 0.06 0.43]
# ThumbUp [0.21 0.3  0.06 0.43]
# ThumbUp [0.22 0.3  0.06 0.42]
# ThumbUp [0.21 0.3  0.06 0.43]
# ThumbUp [0.21 0.3  0.06 0.43]
# ThumbUp [0.22 0.3  0.06 0.42]
# ThumbUp [0.22 0.3  0.06 0.42]
# ThumbUp [0.21 0.3  0.06 0.43]
# ThumbUp [0.21 0.3  0.05 0.44]
# ThumbUp [0.2  0.3  0.06 0.44]
# ThumbUp [0.2  0.3  0.06 0.44]
# ThumbUp [0.19 0.33 0.06 0.42]
# ThumbUp [0.19 0.33 0.06 0.42]
# ThumbUp [0.18 0.34 0.06 0.42]
# ThumbUp [0.17 0.35 0.06 0.42]
# ThumbUp [0.17 0.35 0.06 0.42]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.16 0.36 0.06 0.42]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.18 0.36 0.02 0.44]
# ThumbUp [0.18 0.35 0.05 0.42]
# ThumbUp [0.18 0.34 0.06 0.42]
# ThumbUp [0.18 0.34 0.04 0.44]
# ThumbUp [0.18 0.33 0.06 0.43]
# ThumbUp [0.19 0.33 0.05 0.43]
# ThumbUp [0.19 0.33 0.06 0.42]
# ThumbUp [0.2  0.33 0.06 0.41]
# ThumbUp [0.19 0.33 0.06 0.42]
# ThumbUp [0.18 0.33 0.06 0.43]
# ThumbUp [0.18 0.34 0.05 0.43]
# ThumbUp [0.19 0.34 0.06 0.41]
# ThumbUp [0.2  0.23 0.06 0.51]
# Background [0.41 0.15 0.11 0.33]
# Background [0.47 0.14 0.05 0.34]
# Background [0.46 0.14 0.05 0.35]
# Background [0.43 0.14 0.1  0.33]
# Background [0.45 0.13 0.11 0.31]
# Background [0.51 0.13 0.05 0.31]
# Background [0.51 0.13 0.05 0.31]
# Background [0.58 0.09 0.05 0.28]
# Background [0.66 0.09 0.05 0.2 ]
# Background [0.64 0.09 0.11 0.16]
# Background [0.45 0.05 0.36 0.14]
# Background [0.45 0.05 0.38 0.12]
# Smile [0.39 0.05 0.44 0.12]
# Smile [0.39 0.05 0.46 0.1 ]
# Smile [0.41 0.04 0.43 0.12]
# Smile [0.41 0.04 0.43 0.12]
# Smile [0.4  0.04 0.45 0.11]
# Smile [0.41 0.04 0.43 0.12]
# Background [0.72 0.05 0.11 0.12]
# Background [0.76 0.05 0.07 0.12]
# Background [0.79 0.04 0.06 0.11]
# Background [0.79 0.04 0.07 0.1 ]
# Background [0.8  0.04 0.07 0.09]
# Background [0.8  0.04 0.05 0.11]
# Background [0.82 0.03 0.07 0.08]
# Background [0.54 0.01 0.36 0.09]
# Background [0.53 0.01 0.4  0.06]
# Background [0.48 0.01 0.46 0.05]
# Background [0.48 0.01 0.46 0.05]
# Smile [0.45 0.01 0.48 0.06]
# Background [0.47 0.01 0.45 0.07]
# Smile [0.46 0.01 0.48 0.05]
# Background [0.48 0.01 0.46 0.05]
# Smile [0.45 0.01 0.48 0.06]
# Background [0.5  0.01 0.43 0.06]
# Smile [0.45 0.01 0.48 0.06]
# Smile [0.46 0.01 0.47 0.06]
# Background [0.47 0.01 0.46 0.06]
# Background [0.48 0.01 0.45 0.06]
# Background [0.5  0.01 0.43 0.06]
# Background [0.49 0.01 0.44 0.06]
# Smile [0.45 0.01 0.48 0.06]
# Background [0.5  0.01 0.43 0.06]
# Background [0.5  0.01 0.43 0.06]
# Smile [0.45 0.01 0.48 0.06]
# Background [0.5  0.01 0.43 0.06]
# Background [0.5  0.01 0.43 0.06]
# Smile [0.4  0.01 0.53 0.06]
# Smile [0.38 0.01 0.55 0.06]
# Smile [0.41 0.01 0.51 0.07]
# Smile [0.39 0.01 0.53 0.07]
# Smile [0.45 0.01 0.48 0.06]
# Smile [0.4  0.01 0.53 0.06]
# Smile [0.45 0.01 0.48 0.06]
# Smile [0.45 0.01 0.48 0.06]
# Smile [0.4  0.01 0.53 0.06]
# Smile [0.37 0.01 0.55 0.07]
# Smile [0.45 0.01 0.48 0.06]
# Smile [0.45 0.01 0.46 0.08]
# Smile [0.39 0.01 0.53 0.07]
# Smile [0.42 0.01 0.5  0.07]
# Smile [0.34 0.01 0.59 0.06]
# Smile [0.36 0.01 0.56 0.07]
# Smile [0.31 0.01 0.63 0.05]
# Smile [0.26 0.01 0.68 0.05]
# Smile [0.32 0.01 0.62 0.05]
# Smile [0.37 0.01 0.56 0.06]
# Smile [0.38 0.01 0.55 0.06]
# Background [0.51 0.01 0.42 0.06]
# Background [0.52 0.01 0.41 0.06]
# Background [0.7  0.02 0.23 0.05]
# Background [0.76 0.02 0.15 0.07]
# Background [0.79 0.02 0.12 0.07]
# Background [0.83 0.03 0.07 0.07]
# Background [0.83 0.03 0.06 0.08]
# Background [0.84 0.03 0.05 0.08]
# Background [0.86 0.03 0.03 0.08]
# Background [0.83 0.03 0.06 0.08]
# Background [0.8  0.03 0.11 0.06]
# Background [0.55 0.01 0.38 0.06]
# Background [0.58 0.01 0.34 0.07]
# Background [0.54 0.01 0.39 0.06]
# Background [0.55 0.01 0.38 0.06]
# Background [0.55 0.01 0.37 0.07]
# Background [0.51 0.01 0.41 0.07]
# Background [0.55 0.01 0.37 0.07]
# Background [0.5  0.01 0.43 0.06]
# Background [0.48 0.01 0.44 0.07]
# Background [0.5  0.01 0.43 0.06]
# Smile [0.35 0.01 0.59 0.05]
# Smile [0.3  0.01 0.64 0.05]
# Smile [0.23 0.01 0.71 0.05]
# Smile [0.27 0.01 0.67 0.05]
# Smile [0.42 0.01 0.5  0.07]
# Smile [0.43 0.01 0.49 0.07]
# Smile [0.42 0.01 0.51 0.06]
# Background [0.47 0.01 0.45 0.07]
# Background [0.52 0.01 0.4  0.07]
# Background [0.53 0.01 0.4  0.06]
# Background [0.55 0.01 0.37 0.07]
# Background [0.49 0.01 0.44 0.06]
# Background [0.49 0.01 0.44 0.06]
# Background [0.55 0.01 0.38 0.06]
# Background [0.72 0.02 0.2  0.06]
# Background [0.71 0.02 0.2  0.07]
# Background [0.55 0.01 0.38 0.06]
# Smile [0.46 0.01 0.48 0.05]
# Background [0.49 0.01 0.45 0.05]
# Smile [0.39 0.01 0.55 0.05]
# Background [0.52 0.01 0.42 0.05]
# Smile [0.39 0.01 0.55 0.05]
# Smile [0.42 0.01 0.51 0.06]
# Smile [0.42 0.01 0.51 0.06]
# Smile [0.43 0.01 0.5  0.06]
# Smile [0.4  0.01 0.53 0.06]
# Smile [0.37 0.01 0.56 0.06]
# Smile [0.39 0.01 0.54 0.06]
# Smile [0.42 0.01 0.51 0.06]
# Background [0.48 0.01 0.45 0.06]
# Smile [0.38 0.01 0.55 0.06]
# Background [0.47 0.01 0.46 0.06]
# Smile [0.46 0.01 0.47 0.06]
# Background [0.48 0.01 0.45 0.06]
# Smile [0.44 0.01 0.49 0.06]
# Background [0.48 0.01 0.45 0.06]
# Smile [0.45 0.01 0.49 0.05]
# Background [0.54 0.01 0.38 0.07]
# Smile [0.39 0.01 0.55 0.05]
# Smile [0.38 0.01 0.55 0.06]
# Smile [0.4  0.01 0.53 0.06]
# Smile [0.39 0.01 0.55 0.05]
# Smile [0.36 0.01 0.58 0.05]
# Smile [0.44 0.01 0.5  0.05]
# Smile [0.36 0.01 0.57 0.06]
# Smile [0.34 0.01 0.6  0.05]
# Smile [0.34 0.02 0.56 0.08]
# Background [0.62 0.02 0.2  0.16]
# Background [0.73 0.03 0.06 0.18]
# Background [0.53 0.01 0.31 0.15]
# Background [0.79 0.02 0.1  0.09]
# Background [0.63 0.01 0.28 0.08]
# Background [0.6  0.01 0.31 0.08]
# Background [0.61 0.01 0.3  0.08]
# Background [0.58 0.01 0.34 0.07]
# Background [0.7  0.01 0.18 0.11]
# Background [0.54 0.01 0.38 0.07]
# Smile [0.43 0.01 0.5  0.06]
# Background [0.51 0.01 0.41 0.07]
# Smile [0.32 0.01 0.62 0.05]
# Smile [0.33 0.01 0.61 0.05]
# Smile [0.36 0.01 0.59 0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.33 0.01 0.62 0.04]
# Smile [0.31 0.01 0.63 0.05]
# Smile [0.33 0.01 0.62 0.04]
# Smile [0.33 0.01 0.62 0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.31 0.01 0.63 0.05]
# Smile [0.33 0.01 0.62 0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.36 0.01 0.59 0.04]
# Smile [0.36 0.01 0.59 0.04]
# Smile [0.35 0.01 0.6  0.04]
# Smile [0.34 0.01 0.61 0.04]
# Smile [0.39 0.01 0.55 0.05]
# Smile [0.36 0.01 0.58 0.05]
# Smile [0.36 0.02 0.58 0.04]
# Smile [0.34 0.02 0.59 0.05]
# Smile [0.39 0.02 0.53 0.06]
# Smile [0.33 0.02 0.6  0.05]
# Smile [0.36 0.01 0.58 0.05]
# Background [0.49 0.01 0.43 0.07]
# Background [0.63 0.02 0.26 0.09]
# Background [0.57 0.01 0.34 0.08]
# Background [0.53 0.01 0.38 0.08]
# Background [0.51 0.01 0.4  0.08]
# Background [0.6  0.01 0.3  0.09]
# Background [0.58 0.01 0.32 0.09]
# Background [0.58 0.01 0.33 0.08]
# Background [0.77 0.03 0.09 0.11]
# Background [0.72 0.03 0.15 0.1 ]
# Background [0.64 0.02 0.24 0.1 ]
# Background [0.58 0.02 0.32 0.08]
# Background [0.63 0.02 0.26 0.09]
# Background [0.65 0.02 0.23 0.1 ]
# Background [0.63 0.02 0.26 0.09]
# Background [0.63 0.02 0.26 0.09]
# Background [0.59 0.02 0.3  0.09]
# Background [0.52 0.02 0.41 0.05]
# Background [0.5  0.02 0.42 0.06]
# Background [0.81 0.03 0.08 0.08]
# Background [0.81 0.03 0.03 0.13]
# Background [0.78 0.05 0.01 0.16]
# Background [0.77 0.05 0.01 0.17]
# Background [0.7  0.04 0.01 0.25]
# Background [0.48 0.02 0.03 0.47]
# ThumbUp [0.43 0.03 0.06 0.48]
# ThumbUp [0.39 0.05 0.15 0.41]
# Smile [0.23 0.09 0.35 0.33]
# Smile [0.2  0.09 0.58 0.13]
# Smile [0.14 0.05 0.73 0.08]
# Smile [0.29 0.08 0.52 0.11]
# Smile [0.24 0.09 0.41 0.26]
# Smile [0.12 0.02 0.67 0.19]
# Smile [0.04 0.03 0.73 0.2 ]
# Smile [0.03 0.   0.87 0.1 ]
# Smile [0.03 0.02 0.89 0.06]
# Smile [0.03 0.06 0.84 0.07]
# Smile [0.03 0.01 0.87 0.09]
# Smile [0.04 0.08 0.81 0.07]
# Smile [0.05 0.1  0.8  0.05]
# Smile [0.07 0.05 0.81 0.07]
# Smile [0.08 0.01 0.83 0.08]
# Smile [0.14 0.02 0.75 0.09]
# Smile [0.23 0.02 0.64 0.11]
# Smile [0.41 0.06 0.48 0.05]
# Smile [0.38 0.04 0.49 0.09]
# Smile [0.17 0.02 0.69 0.12]
# Smile [0.03 0.   0.97 0.  ]
# Smile [0.05 0.01 0.93 0.01]
# Smile [0.05 0.   0.94 0.01]
# Background [0.48 0.07 0.42 0.03]
# Background [0.72 0.08 0.16 0.04]
# Background [0.62 0.06 0.28 0.04]
# Background [0.56 0.01 0.34 0.09]
# Smile [0.46 0.01 0.47 0.06]
# Smile [0.43 0.02 0.49 0.06]
# Background [0.61 0.02 0.29 0.08]
# Background [0.47 0.   0.47 0.06]
# Background [0.51 0.   0.4  0.09]
# Smile [0.21 0.01 0.72 0.06]
# Smile [0.18 0.01 0.76 0.05]
# Smile [0.14 0.   0.81 0.05]
# Smile [0.06 0.   0.92 0.02]
# Smile [0.01 0.   0.98 0.01]
# Smile [0.02 0.   0.97 0.01]
# Smile [0.04 0.   0.96 0.  ]
# Smile [0.02 0.12 0.81 0.05]
# Smile [0.02 0.13 0.81 0.04]
# Smile [0.04 0.16 0.74 0.06]
# Smile [0.09 0.25 0.5  0.16]
# Question [0.27 0.41 0.07 0.25]
# Question [0.34 0.46 0.07 0.13]
# Background [0.47 0.41 0.02 0.1 ]
# Background [0.39 0.37 0.11 0.13]
# Question [0.32 0.4  0.13 0.15]
# Background [0.53 0.37 0.05 0.05]
# Background [0.59 0.34 0.03 0.04]
# Background [0.66 0.3  0.03 0.01]
# Background [0.58 0.35 0.03 0.04]
# Question [0.35 0.38 0.12 0.15]
# Smile [0.22 0.3  0.37 0.11]
# Smile [0.11 0.18 0.67 0.04]
# Smile [0.1  0.14 0.73 0.03]
# Smile [0.04 0.12 0.82 0.02]
# Smile [0.05 0.12 0.81 0.02]
# Smile [0.04 0.01 0.95 0.  ]
# Smile [0.03 0.   0.97 0.  ]
# Smile [0.03 0.   0.97 0.  ]
# Smile [0.07 0.   0.86 0.07]
# Smile [0.05 0.02 0.7  0.23]
# Smile [0.01 0.   0.84 0.15]
# Smile [0.02 0.   0.81 0.17]
# Smile [0.01 0.   0.88 0.11]
# Smile [0.01 0.01 0.88 0.1 ]
# Smile [0.02 0.   0.84 0.14]
# Smile [0.02 0.   0.87 0.11]
# Smile [0.01 0.   0.94 0.05]
# Smile [0.01 0.   0.89 0.1 ]
# Smile [0.06 0.03 0.52 0.39]
# ThumbUp [0.07 0.05 0.36 0.52]
# Smile [0.12 0.03 0.6  0.25]
# Smile [0.12 0.02 0.69 0.17]
# Smile [0.12 0.02 0.67 0.19]
# Smile [0.1  0.02 0.7  0.18]
# Smile [0.1  0.02 0.7  0.18]
# Smile [0.03 0.   0.79 0.18]
# Smile [0.04 0.   0.87 0.09]
# Smile [0.02 0.   0.91 0.07]
# Smile [0.02 0.   0.94 0.04]
# Smile [0.03 0.   0.91 0.06]
# Smile [0.07 0.   0.86 0.07]
# Smile [0.04 0.   0.9  0.06]
# Smile [0.05 0.   0.89 0.06]
# Smile [0.02 0.   0.93 0.05]
# Smile [0.02 0.   0.93 0.05]
# Smile [0.01 0.01 0.86 0.12]
# Smile [0.01 0.   0.87 0.12]
# Smile [0.02 0.01 0.79 0.18]
# Smile [0.02 0.01 0.84 0.13]
# Smile [0.02 0.01 0.82 0.15]
# Smile [0.01 0.01 0.86 0.12]
# Smile [0.01 0.01 0.9  0.08]
# Smile [0.01 0.01 0.91 0.07]
# Smile [0.01 0.   0.91 0.08]
# Smile [0.01 0.   0.91 0.08]
# Smile [0.01 0.   0.91 0.08]
# Smile [0.02 0.   0.92 0.06]
# Smile [0.01 0.   0.91 0.08]
# Smile [0.11 0.   0.69 0.2 ]
# Smile [0.01 0.   0.89 0.1 ]
# Smile [0.02 0.   0.91 0.07]
# Smile [0.02 0.   0.86 0.12]
# Smile [0.01 0.   0.93 0.06]
# Smile [0.01 0.   0.89 0.1 ]
# Smile [0.01 0.   0.87 0.12]
# Smile [0.02 0.   0.85 0.13]
# Smile [0.02 0.   0.89 0.09]
# Smile [0.02 0.   0.85 0.13]
# Smile [0.01 0.02 0.84 0.13]
# Smile [0.01 0.02 0.85 0.12]
# ThumbUp [0.05 0.1  0.1  0.75]
# ThumbUp [0.03 0.09 0.18 0.7 ]
# Smile [0.01 0.02 0.84 0.13]
# Smile [0.01 0.02 0.83 0.14]
# ThumbUp [0.01 0.11 0.19 0.69]
# Smile [0.01 0.   0.86 0.13]
# Smile [0.01 0.   0.86 0.13]
# Smile [0.01 0.   0.86 0.13]
# Smile [0.01 0.01 0.85 0.13]
# Smile [0.01 0.01 0.85 0.13]
# Smile [0.01 0.01 0.84 0.14]
# Smile [0.01 0.01 0.84 0.14]
# Smile [0.01 0.01 0.85 0.13]
# Smile [0.01 0.01 0.86 0.12]
# Smile [0.01 0.01 0.84 0.14]
# Smile [0.01 0.01 0.84 0.14]
# Smile [0.01 0.01 0.86 0.12]
# Smile [0.03 0.   0.88 0.09]
# Smile [0.02 0.   0.91 0.07]
# Smile [0.02 0.   0.89 0.09]
# Smile [0.02 0.   0.86 0.12]
# Smile [0.02 0.   0.87 0.11]
# Smile [0.01 0.   0.88 0.11]
# Smile [0.01 0.   0.91 0.08]
# Smile [0.01 0.   0.9  0.09]
# Smile [0.01 0.   0.87 0.12]
# Smile [0.02 0.01 0.86 0.11]
# Smile [0.01 0.01 0.87 0.11]
# Smile [0.02 0.   0.88 0.1 ]
# Smile [0.03 0.   0.89 0.08]
# Smile [0.03 0.   0.89 0.08]
# Smile [0.03 0.   0.89 0.08]
# Smile [0.03 0.   0.87 0.1 ]
# Smile [0.03 0.   0.88 0.09]
# Smile [0.03 0.   0.88 0.09]
# Smile [0.03 0.   0.89 0.08]
# Smile [0.02 0.   0.86 0.12]
# Smile [0.02 0.   0.88 0.1 ]
# Smile [0.03 0.   0.91 0.06]
# Smile [0.03 0.   0.91 0.06]
# Smile [0.03 0.   0.91 0.06]
# Smile [0.03 0.   0.92 0.05]
# Smile [0.03 0.   0.89 0.08]
# Smile [0.03 0.   0.91 0.06]
# Smile [0.03 0.   0.88 0.09]
# Smile [0.02 0.   0.93 0.05]
# Smile [0.02 0.   0.88 0.1 ]
# Smile [0.02 0.   0.9  0.08]
# Smile [0.03 0.   0.92 0.05]
# Smile [0.02 0.   0.93 0.05]
# Smile [0.03 0.   0.93 0.04]
# Smile [0.02 0.   0.94 0.04]
# Smile [0.02 0.01 0.92 0.05]
# Smile [0.02 0.01 0.91 0.06]
# Smile [0.03 0.01 0.89 0.07]
# Smile [0.03 0.   0.92 0.05]
# Smile [0.03 0.   0.92 0.05]
# Smile [0.02 0.   0.94 0.04]
# Smile [0.02 0.   0.94 0.04]
# Smile [0.03 0.   0.92 0.05]
# Smile [0.03 0.   0.92 0.05]
# Smile [0.03 0.   0.89 0.08]
# Smile [0.03 0.   0.92 0.05]
# Smile [0.04 0.   0.88 0.08]
# Smile [0.04 0.   0.88 0.08]
# Smile [0.04 0.   0.85 0.11]
# Smile [0.1  0.   0.77 0.13]
# Smile [0.04 0.   0.88 0.08]
# Smile [0.04 0.   0.86 0.1 ]
# Smile [0.04 0.   0.88 0.08]
# Smile [0.04 0.   0.88 0.08]
# Smile [0.04 0.   0.89 0.07]
# Smile [0.04 0.   0.89 0.07]
# Smile [0.05 0.02 0.7  0.23]
# Smile [0.09 0.01 0.75 0.15]
# Smile [0.09 0.   0.77 0.14]
# Smile [0.1  0.   0.76 0.14]
# Smile [0.1  0.   0.76 0.14]
# Smile [0.1  0.01 0.74 0.15]
# Smile [0.1  0.01 0.75 0.14]
# Smile [0.09 0.   0.77 0.14]
# Smile [0.11 0.   0.78 0.11]
# Smile [0.11 0.01 0.75 0.13]
# Smile [0.11 0.   0.76 0.13]
# Smile [0.11 0.   0.76 0.13]
# Smile [0.11 0.01 0.75 0.13]
# Smile [0.13 0.01 0.72 0.14]
# Smile [0.2  0.01 0.56 0.23]
# ThumbUp [0.38 0.03 0.09 0.5 ]
# ThumbUp [0.41 0.05 0.01 0.53]
# ThumbUp [0.29 0.11 0.01 0.59]
# ThumbUp [0.28 0.08 0.02 0.62]
# ThumbUp [0.39 0.1  0.03 0.48]
# ThumbUp [0.39 0.08 0.04 0.49]
# ThumbUp [0.39 0.09 0.03 0.49]
# Background [0.46 0.07 0.04 0.43]
# Background [0.45 0.07 0.07 0.41]
# ThumbUp [0.42 0.06 0.08 0.44]
# ThumbUp [0.37 0.07 0.15 0.41]
# Smile [0.17 0.04 0.41 0.38]
# Smile [0.07 0.03 0.75 0.15]
# Smile [0.01 0.01 0.94 0.04]
# Smile [0.01 0.01 0.94 0.04]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.97 0.01]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.01 0.97 0.01]
# Smile [0.01 0.01 0.96 0.02]
# Smile [0.01 0.01 0.95 0.03]
# Smile [0.01 0.03 0.94 0.02]
# Smile [0.01 0.02 0.95 0.02]
# Smile [0.01 0.02 0.95 0.02]
# Smile [0.01 0.03 0.94 0.02]
# Smile [0.01 0.03 0.94 0.02]
# Smile [0.01 0.03 0.94 0.02]
# Smile [0.01 0.03 0.94 0.02]
# Smile [0.01 0.03 0.95 0.01]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.03 0.95 0.01]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.03 0.94 0.02]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.05 0.92 0.02]
# Smile [0.01 0.01 0.98 0.  ]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.02 0.97 0.  ]
# Smile [0.01 0.01 0.98 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.01 0.97 0.01]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.01 0.   0.99 0.  ]
# Smile [0.02 0.02 0.95 0.01]
# Smile [0.18 0.04 0.52 0.26]
# Smile [0.33 0.04 0.43 0.2 ]
# Background [0.94 0.01 0.03 0.02]
# Background [0.86 0.03 0.01 0.1 ]
# Background [0.42 0.03 0.35 0.2 ]
# Smile [0.39 0.02 0.43 0.16]
# Smile [0.31 0.01 0.5  0.18]
# Smile [0.32 0.02 0.46 0.2 ]
# Smile [0.28 0.03 0.5  0.19]
# Smile [0.09 0.02 0.76 0.13]
# Smile [0.21 0.05 0.58 0.16]
# Background [0.5  0.14 0.09 0.27]
# Background [0.49 0.14 0.11 0.26]
# Background [0.49 0.14 0.11 0.26]
# Background [0.48 0.14 0.12 0.26]
# Smile [0.26 0.08 0.49 0.17]
# Smile [0.22 0.06 0.54 0.18]
# Smile [0.21 0.05 0.6  0.14]
# Smile [0.23 0.06 0.54 0.17]
# Smile [0.27 0.08 0.49 0.16]
# Smile [0.28 0.07 0.49 0.16]
# Smile [0.28 0.08 0.49 0.15]
# Smile [0.28 0.07 0.49 0.16]
# Smile [0.26 0.12 0.34 0.28]
# ThumbUp [0.29 0.17 0.13 0.41]
# ThumbUp [0.29 0.17 0.13 0.41]
# ThumbUp [0.3  0.17 0.12 0.41]
# ThumbUp [0.3  0.17 0.11 0.42]
# ThumbUp [0.31 0.17 0.1  0.42]
# Smile [0.23 0.13 0.32 0.32]
# Smile [0.21 0.09 0.46 0.24]
# Smile [0.21 0.09 0.46 0.24]
# Smile [0.19 0.12 0.43 0.26]
# Smile [0.2  0.14 0.36 0.3 ]
# Smile [0.24 0.12 0.37 0.27]
# Smile [0.18 0.11 0.43 0.28]
# Smile [0.18 0.11 0.44 0.27]
# Smile [0.2  0.1  0.46 0.24]
# Smile [0.21 0.1  0.46 0.23]
# Smile [0.2  0.1  0.47 0.23]
# Smile [0.2  0.1  0.46 0.24]
# Smile [0.24 0.12 0.34 0.3 ]
# ThumbUp [0.23 0.15 0.27 0.35]
# ThumbUp [0.22 0.16 0.27 0.35]
# ThumbUp [0.34 0.15 0.16 0.35]
# ThumbUp [0.24 0.15 0.25 0.36]
# Smile [0.21 0.11 0.43 0.25]
# Smile [0.2  0.1  0.46 0.24]
# Smile [0.22 0.11 0.45 0.22]
# Smile [0.18 0.1  0.47 0.25]
# Smile [0.17 0.11 0.5  0.22]
# Smile [0.17 0.11 0.51 0.21]
# Smile [0.15 0.09 0.56 0.2 ]
# Smile [0.13 0.09 0.56 0.22]
# Smile [0.12 0.1  0.55 0.23]
# Smile [0.14 0.14 0.47 0.25]
# Smile [0.11 0.11 0.55 0.23]
# Smile [0.1  0.11 0.55 0.24]
# Smile [0.12 0.15 0.47 0.26]
# Smile [0.1  0.12 0.55 0.23]
# Smile [0.1  0.11 0.55 0.24]
# Smile [0.11 0.13 0.53 0.23]
# Smile [0.11 0.1  0.55 0.24]
# Smile [0.1  0.12 0.55 0.23]
# Smile [0.1  0.12 0.55 0.23]
# Smile [0.07 0.09 0.64 0.2 ]
# Smile [0.07 0.1  0.59 0.24]
# Smile [0.07 0.1  0.6  0.23]
# Smile [0.07 0.1  0.62 0.21]
# Smile [0.1  0.1  0.56 0.24]
# Smile [0.1  0.11 0.55 0.24]
# Smile [0.09 0.11 0.55 0.25]
# Smile [0.1  0.12 0.55 0.23]
# Smile [0.11 0.15 0.5  0.24]
# Smile [0.17 0.16 0.39 0.28]
# Smile [0.18 0.17 0.36 0.29]
# Smile [0.25 0.13 0.39 0.23]
# Smile [0.27 0.13 0.38 0.22]
# Smile [0.26 0.13 0.39 0.22]
# Smile [0.27 0.13 0.36 0.24]
# Smile [0.27 0.13 0.38 0.22]
# Smile [0.27 0.13 0.34 0.26]
# Smile [0.25 0.13 0.39 0.23]
# Smile [0.17 0.14 0.4  0.29]
# Smile [0.14 0.16 0.39 0.31]
# Smile [0.14 0.18 0.39 0.29]
# Smile [0.13 0.21 0.39 0.27]
# Smile [0.14 0.22 0.36 0.28]
# Smile [0.12 0.2  0.4  0.28]
# Smile [0.13 0.2  0.4  0.27]
# Smile [0.14 0.22 0.35 0.29]
# Smile [0.16 0.21 0.34 0.29]
# Smile [0.14 0.22 0.36 0.28]
# Smile [0.13 0.23 0.33 0.31]
# Smile [0.13 0.23 0.36 0.28]
# Smile [0.12 0.23 0.39 0.26]
# Smile [0.13 0.24 0.36 0.27]
# ThumbUp [0.13 0.27 0.24 0.36]
# ThumbUp [0.17 0.3  0.13 0.4 ]
# ThumbUp [0.16 0.3  0.13 0.41]
# ThumbUp [0.18 0.3  0.11 0.41]
# ThumbUp [0.17 0.31 0.11 0.41]
# ThumbUp [0.18 0.3  0.12 0.4 ]
# ThumbUp [0.15 0.3  0.12 0.43]
# ThumbUp [0.15 0.29 0.13 0.43]
# ThumbUp [0.15 0.29 0.13 0.43]
# ThumbUp [0.15 0.3  0.13 0.42]
# ThumbUp [0.15 0.28 0.16 0.41]
# Smile [0.11 0.22 0.38 0.29]
# Smile [0.08 0.2  0.5  0.22]
# Smile [0.08 0.21 0.44 0.27]
# Smile [0.08 0.21 0.44 0.27]
# Smile [0.08 0.2  0.47 0.25]
# Smile [0.1  0.22 0.41 0.27]
# Smile [0.1  0.2  0.44 0.26]
# Smile [0.1  0.2  0.45 0.25]
# Smile [0.1  0.21 0.42 0.27]
# Smile [0.1  0.2  0.44 0.26]
# Smile [0.1  0.22 0.41 0.27]
# Smile [0.1  0.21 0.42 0.27]
# Smile [0.1  0.22 0.41 0.27]
# Smile [0.1  0.22 0.41 0.27]
# Smile [0.1  0.22 0.41 0.27]
# Smile [0.1  0.2  0.45 0.25]
# Smile [0.1  0.2  0.44 0.26]
# Smile [0.12 0.16 0.42 0.3 ]
# Smile [0.15 0.14 0.44 0.27]
# Background [0.32 0.13 0.24 0.31]
# Background [0.35 0.13 0.22 0.3 ]
# Background [0.33 0.13 0.23 0.31]
# Background [0.35 0.13 0.21 0.31]
# Background [0.36 0.14 0.18 0.32]
# Background [0.34 0.13 0.21 0.32]
# Background [0.39 0.15 0.12 0.34]
# Background [0.35 0.14 0.2  0.31]
# Background [0.36 0.13 0.2  0.31]
# Background [0.36 0.14 0.19 0.31]
# Background [0.33 0.13 0.21 0.33]
# ThumbUp [0.23 0.19 0.11 0.47]
# ThumbUp [0.18 0.29 0.12 0.41]
# ThumbUp [0.21 0.29 0.11 0.39]
# Question [0.23 0.26 0.26 0.25]
# Smile [0.14 0.24 0.42 0.2 ]
# Smile [0.22 0.22 0.38 0.18]
# Smile [0.2  0.24 0.35 0.21]
# Smile [0.19 0.24 0.38 0.19]
# Smile [0.22 0.24 0.33 0.21]
# Smile [0.24 0.22 0.37 0.17]
# Smile [0.23 0.21 0.4  0.16]
# Smile [0.21 0.21 0.44 0.14]
# Smile [0.22 0.21 0.42 0.15]
# Smile [0.26 0.21 0.38 0.15]
# Smile [0.24 0.21 0.4  0.15]
# Smile [0.27 0.21 0.38 0.14]
# Smile [0.27 0.21 0.38 0.14]
# Question [0.25 0.27 0.23 0.25]
# Question [0.19 0.29 0.23 0.29]
# Question [0.18 0.34 0.14 0.34]
# ThumbUp [0.19 0.25 0.12 0.44]
# ThumbUp [0.21 0.25 0.11 0.43]
# Background [0.39 0.17 0.14 0.3 ]
# Background [0.41 0.17 0.12 0.3 ]
# Background [0.41 0.17 0.11 0.31]
# Background [0.41 0.17 0.11 0.31]
# Background [0.4  0.17 0.13 0.3 ]
# Background [0.4  0.17 0.13 0.3 ]
# Background [0.38 0.17 0.13 0.32]
# ThumbUp [0.22 0.22 0.13 0.43]
# ThumbUp [0.22 0.22 0.12 0.44]
# ThumbUp [0.2  0.33 0.12 0.35]
# Question [0.17 0.31 0.21 0.31]
# ThumbUp [0.17 0.31 0.19 0.33]
# ThumbUp [0.17 0.31 0.2  0.32]
# ThumbUp [0.17 0.31 0.19 0.33]
# ThumbUp [0.17 0.31 0.19 0.33]
# ThumbUp [0.17 0.31 0.2  0.32]
# ThumbUp [0.16 0.31 0.21 0.32]
# ThumbUp [0.17 0.31 0.2  0.32]
# ThumbUp [0.17 0.31 0.19 0.33]
# Question [0.15 0.3  0.26 0.29]
# ThumbUp [0.16 0.3  0.22 0.32]
# Question [0.15 0.31 0.24 0.3 ]
# Question [0.14 0.31 0.26 0.29]
# Question [0.16 0.31 0.23 0.3 ]
# Question [0.15 0.32 0.26 0.27]
# Question [0.17 0.31 0.25 0.27]
# Question [0.15 0.3  0.29 0.26]
# Question [0.16 0.3  0.29 0.25]
# Question [0.17 0.31 0.24 0.28]
# Smile [0.13 0.3  0.33 0.24]
# Smile [0.1  0.28 0.4  0.22]
# Smile [0.07 0.24 0.49 0.2 ]
# Smile [0.07 0.22 0.51 0.2 ]
# Smile [0.07 0.23 0.5  0.2 ]
# Smile [0.07 0.24 0.49 0.2 ]
# Smile [0.09 0.24 0.46 0.21]
# Smile [0.09 0.24 0.45 0.22]
# Smile [0.07 0.23 0.49 0.21]
# Smile [0.09 0.24 0.46 0.21]
# Smile [0.07 0.24 0.48 0.21]
# Smile [0.06 0.23 0.49 0.22]
# Smile [0.05 0.21 0.48 0.26]
# Smile [0.03 0.14 0.57 0.26]
# Smile [0.03 0.18 0.48 0.31]
# Smile [0.06 0.23 0.37 0.34]
# Question [0.13 0.29 0.29 0.29]
# ThumbUp [0.17 0.32 0.05 0.46]
# ThumbUp [0.18 0.31 0.   0.51]
# ThumbUp [0.11 0.25 0.08 0.56]
# ThumbUp [0.1  0.24 0.06 0.6 ]
# ThumbUp [0.09 0.23 0.13 0.55]
# ThumbUp [0.07 0.22 0.17 0.54]
# ThumbUp [0.06 0.21 0.25 0.48]
# ThumbUp [0.06 0.21 0.27 0.46]
# ThumbUp [0.06 0.21 0.33 0.4 ]
# ThumbUp [0.07 0.22 0.25 0.46]
# ThumbUp [0.07 0.22 0.24 0.47]
# ThumbUp [0.07 0.21 0.21 0.51]
# ThumbUp [0.07 0.22 0.23 0.48]
# ThumbUp [0.07 0.22 0.23 0.48]
# ThumbUp [0.07 0.23 0.24 0.46]
# ThumbUp [0.05 0.21 0.35 0.39]
# ThumbUp [0.05 0.22 0.31 0.42]
# ThumbUp [0.05 0.22 0.31 0.42]
# ThumbUp [0.05 0.22 0.28 0.45]
# ThumbUp [0.07 0.25 0.11 0.57]
# ThumbUp [0.08 0.25 0.1  0.57]
# ThumbUp [0.08 0.24 0.07 0.61]
# ThumbUp [0.05 0.24 0.17 0.54]
# ThumbUp [0.04 0.21 0.35 0.4 ]
# ThumbUp [0.05 0.21 0.34 0.4 ]
# ThumbUp [0.06 0.23 0.21 0.5 ]
# ThumbUp [0.06 0.23 0.21 0.5 ]
# ThumbUp [0.06 0.23 0.21 0.5 ]
# ThumbUp [0.06 0.23 0.21 0.5 ]
# ThumbUp [0.06 0.22 0.25 0.47]
# ThumbUp [0.06 0.23 0.21 0.5 ]
# ThumbUp [0.06 0.22 0.25 0.47]
# ThumbUp [0.06 0.21 0.29 0.44]
# ThumbUp [0.04 0.21 0.35 0.4 ]
# ThumbUp [0.04 0.21 0.35 0.4 ]
# ThumbUp [0.06 0.23 0.25 0.46]
# Smile [0.03 0.18 0.42 0.37]
# Smile [0.03 0.14 0.56 0.27]
# Smile [0.02 0.12 0.6  0.26]
# Smile [0.01 0.11 0.63 0.25]
# Smile [0.02 0.11 0.62 0.25]
# Smile [0.01 0.08 0.67 0.24]
# Smile [0.02 0.11 0.62 0.25]
# ThumbUp [0.07 0.21 0.22 0.5 ]
# ThumbUp [0.08 0.17 0.11 0.64]
# ThumbUp [0.06 0.17 0.16 0.61]
# ThumbUp [0.09 0.17 0.05 0.69]
# ThumbUp [0.09 0.22 0.05 0.64]
# ThumbUp [0.09 0.22 0.09 0.6 ]
# ThumbUp [0.06 0.21 0.26 0.47]
# ThumbUp [0.1  0.22 0.01 0.67]
# ThumbUp [0.09 0.23 0.06 0.62]
# ThumbUp [0.09 0.21 0.06 0.64]
# ThumbUp [0.09 0.23 0.06 0.62]
# ThumbUp [0.09 0.23 0.1  0.58]
# ThumbUp [0.09 0.23 0.08 0.6 ]
# ThumbUp [0.08 0.23 0.11 0.58]
# ThumbUp [0.09 0.23 0.08 0.6 ]
# ThumbUp [0.09 0.23 0.07 0.61]
# ThumbUp [0.09 0.23 0.1  0.58]
# ThumbUp [0.08 0.23 0.06 0.63]
# ThumbUp [0.08 0.23 0.06 0.63]
# ThumbUp [0.09 0.23 0.06 0.62]
# ThumbUp [0.09 0.23 0.07 0.61]
# ThumbUp [0.08 0.23 0.12 0.57]
# ThumbUp [0.08 0.23 0.15 0.54]
# ThumbUp [0.06 0.22 0.23 0.49]
# ThumbUp [0.06 0.17 0.23 0.54]
# ThumbUp [0.06 0.16 0.27 0.51]
# ThumbUp [0.06 0.16 0.26 0.52]
# ThumbUp [0.04 0.15 0.37 0.44]
# Smile [0.03 0.13 0.42 0.42]
# ThumbUp [0.04 0.16 0.36 0.44]
# ThumbUp [0.06 0.14 0.26 0.54]
# ThumbUp [0.06 0.12 0.25 0.57]
# ThumbUp [0.06 0.11 0.3  0.53]
# ThumbUp [0.06 0.17 0.18 0.59]
# ThumbUp [0.06 0.16 0.27 0.51]
# ThumbUp [0.06 0.14 0.33 0.47]
# ThumbUp [0.06 0.16 0.25 0.53]
# ThumbUp [0.06 0.17 0.2  0.57]
# ThumbUp [0.06 0.17 0.21 0.56]
# ThumbUp [0.06 0.17 0.23 0.54]
# ThumbUp [0.06 0.14 0.31 0.49]
# ThumbUp [0.06 0.15 0.2  0.59]
# ThumbUp [0.06 0.1  0.27 0.57]
# ThumbUp [0.06 0.09 0.29 0.56]
# ThumbUp [0.06 0.09 0.29 0.56]
# ThumbUp [0.06 0.1  0.25 0.59]
# ThumbUp [0.06 0.11 0.18 0.65]
# ThumbUp [0.09 0.12 0.1  0.69]
# ThumbUp [0.08 0.12 0.11 0.69]
# ThumbUp [0.06 0.11 0.2  0.63]
# ThumbUp [0.06 0.1  0.23 0.61]
# ThumbUp [0.06 0.08 0.32 0.54]
# ThumbUp [0.05 0.12 0.17 0.66]
# ThumbUp [0.04 0.08 0.39 0.49]
# ThumbUp [0.03 0.07 0.43 0.47]
# Smile [0.03 0.07 0.45 0.45]
# Smile [0.03 0.08 0.46 0.43]
# Smile [0.03 0.09 0.47 0.41]
# Smile [0.03 0.06 0.56 0.35]
# Smile [0.03 0.1  0.54 0.33]
# Smile [0.03 0.11 0.49 0.37]
# Smile [0.03 0.07 0.48 0.42]
# Smile [0.03 0.08 0.5  0.39]
# Smile [0.03 0.08 0.48 0.41]
# Smile [0.03 0.07 0.48 0.42]
# Smile [0.03 0.08 0.49 0.4 ]
# Smile [0.03 0.08 0.48 0.41]
# Smile [0.03 0.06 0.53 0.38]
# Smile [0.03 0.07 0.51 0.39]
# Smile [0.03 0.07 0.5  0.4 ]
# Smile [0.03 0.06 0.52 0.39]
# Smile [0.03 0.07 0.45 0.45]
# Smile [0.03 0.07 0.5  0.4 ]
# ThumbUp [0.04 0.08 0.42 0.46]
# Smile [0.03 0.08 0.45 0.44]
# ThumbUp [0.05 0.09 0.4  0.46]
# Smile [0.03 0.07 0.46 0.44]
# Smile [0.03 0.06 0.49 0.42]
# Smile [0.02 0.04 0.61 0.33]
# ThumbUp [0.04 0.2  0.28 0.48]
# Smile [0.03 0.14 0.5  0.33]
# ThumbUp [0.03 0.16 0.38 0.43]
# Smile [0.03 0.15 0.47 0.35]
# ThumbUp [0.04 0.18 0.33 0.45]
# ThumbUp [0.04 0.18 0.3  0.48]
# ThumbUp [0.07 0.23 0.13 0.57]
# ThumbUp [0.05 0.23 0.23 0.49]
# ThumbUp [0.07 0.25 0.12 0.56]
# ThumbUp [0.09 0.25 0.01 0.65]
# ThumbUp [0.09 0.25 0.01 0.65]
# ThumbUp [0.08 0.25 0.12 0.55]
# ThumbUp [0.08 0.24 0.05 0.63]
# ThumbUp [0.08 0.25 0.11 0.56]
# ThumbUp [0.08 0.24 0.08 0.6 ]
# ThumbUp [0.09 0.25 0.12 0.54]
# ThumbUp [0.09 0.24 0.05 0.62]
# ThumbUp [0.08 0.24 0.08 0.6 ]
# ThumbUp [0.08 0.24 0.05 0.63]
# ThumbUp [0.08 0.24 0.05 0.63]
# ThumbUp [0.08 0.24 0.09 0.59]
# ThumbUp [0.08 0.25 0.09 0.58]
# ThumbUp [0.08 0.24 0.09 0.59]
# ThumbUp [0.08 0.25 0.12 0.55]
# ThumbUp [0.07 0.25 0.14 0.54]
# ThumbUp [0.06 0.24 0.19 0.51]
# ThumbUp [0.08 0.24 0.12 0.56]
# ThumbUp [0.08 0.25 0.07 0.6 ]
# ThumbUp [0.08 0.25 0.05 0.62]
# ThumbUp [0.1  0.25 0.01 0.64]
# ThumbUp [0.1  0.25 0.   0.65]
# ThumbUp [0.1  0.25 0.   0.65]
# ThumbUp [0.08 0.22 0.2  0.5 ]
# ThumbUp [0.08 0.22 0.13 0.57]
# ThumbUp [0.09 0.26 0.   0.65]
# ThumbUp [0.09 0.25 0.   0.66]
# ThumbUp [0.08 0.26 0.   0.66]
# Smile [0.02 0.16 0.47 0.35]
# Smile [0.   0.1  0.69 0.21]
# Smile [0.01 0.16 0.53 0.3 ]
# Smile [0.   0.09 0.73 0.18]
# Smile [0.01 0.1  0.66 0.23]
# Smile [0.02 0.16 0.53 0.29]
# Smile [0.03 0.18 0.41 0.38]
# ThumbUp [0.06 0.17 0.28 0.49]
# ThumbUp [0.11 0.22 0.08 0.59]
# Smile [0.05 0.14 0.42 0.39]
# ThumbUp [0.07 0.15 0.33 0.45]
# Smile [0.05 0.12 0.43 0.4 ]
# Smile [0.06 0.11 0.48 0.35]
# ThumbUp [0.14 0.17 0.09 0.6 ]
# ThumbUp [0.19 0.14 0.08 0.59]
# ThumbUp [0.18 0.16 0.04 0.62]
# ThumbUp [0.18 0.18 0.01 0.63]
# ThumbUp [0.18 0.16 0.   0.66]
# ThumbUp [0.23 0.19 0.02 0.56]
# ThumbUp [0.2  0.21 0.01 0.58]
# ThumbUp [0.17 0.22 0.   0.61]
# ThumbUp [0.17 0.22 0.   0.61]
# ThumbUp [0.18 0.25 0.   0.57]
# ThumbUp [0.18 0.25 0.   0.57]
# ThumbUp [0.17 0.26 0.   0.57]
# ThumbUp [0.17 0.26 0.   0.57]
# ThumbUp [0.17 0.26 0.   0.57]
# ThumbUp [0.17 0.25 0.   0.58]
# ThumbUp [0.17 0.25 0.   0.58]
# ThumbUp [0.2  0.24 0.   0.56]
# ThumbUp [0.21 0.22 0.   0.57]
# ThumbUp [0.2  0.18 0.13 0.49]
# ThumbUp [0.21 0.22 0.01 0.56]
# ThumbUp [0.16 0.2  0.18 0.46]
# ThumbUp [0.15 0.18 0.27 0.4 ]
# ThumbUp [0.13 0.18 0.29 0.4 ]
# Smile [0.11 0.16 0.37 0.36]
# ThumbUp [0.17 0.19 0.2  0.44]
# ThumbUp [0.18 0.21 0.12 0.49]
# ThumbUp [0.18 0.23 0.06 0.53]
# ThumbUp [0.2  0.23 0.03 0.54]
# ThumbUp [0.18 0.22 0.08 0.52]
# ThumbUp [0.18 0.23 0.01 0.58]
# ThumbUp [0.17 0.21 0.12 0.5 ]
# ThumbUp [0.17 0.21 0.1  0.52]
# ThumbUp [0.17 0.22 0.07 0.54]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.   0.6 ]
# ThumbUp [0.16 0.24 0.   0.6 ]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.23 0.06 0.55]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.17 0.23 0.03 0.57]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.   0.6 ]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.16 0.24 0.   0.6 ]
# ThumbUp [0.16 0.24 0.01 0.59]
# ThumbUp [0.14 0.25 0.02 0.59]
# ThumbUp [0.14 0.23 0.07 0.56]
# ThumbUp [0.15 0.23 0.01 0.61]
# ThumbUp [0.13 0.2  0.1  0.57]
# ThumbUp [0.12 0.2  0.07 0.61]
# ThumbUp [0.12 0.2  0.06 0.62]
# ThumbUp [0.12 0.2  0.1  0.58]
# ThumbUp [0.11 0.22 0.07 0.6 ]
# ThumbUp [0.12 0.22 0.07 0.59]
# ThumbUp [0.12 0.21 0.05 0.62]
# ThumbUp [0.11 0.21 0.09 0.59]
# ThumbUp [0.1  0.23 0.07 0.6 ]
# ThumbUp [0.08 0.24 0.12 0.56]
# ThumbUp [0.06 0.17 0.18 0.59]
# ThumbUp [0.06 0.11 0.2  0.63]
# ThumbUp [0.06 0.1  0.23 0.61]
# ThumbUp [0.05 0.11 0.19 0.65]
# ThumbUp [0.06 0.11 0.19 0.64]
# ThumbUp [0.06 0.11 0.19 0.64]
# ThumbUp [0.08 0.12 0.13 0.67]
# ThumbUp [0.08 0.12 0.12 0.68]
# ThumbUp [0.07 0.12 0.13 0.68]
# ThumbUp [0.08 0.12 0.12 0.68]
# ThumbUp [0.05 0.09 0.29 0.57]
# ThumbUp [0.07 0.12 0.11 0.7 ]
# ThumbUp [0.07 0.12 0.12 0.69]
# ThumbUp [0.05 0.11 0.2  0.64]
# ThumbUp [0.08 0.13 0.11 0.68]
# ThumbUp [0.08 0.11 0.05 0.76]
# ThumbUp [0.08 0.11 0.05 0.76]
# ThumbUp [0.09 0.12 0.01 0.78]
# ThumbUp [0.08 0.11 0.06 0.75]
# ThumbUp [0.08 0.12 0.08 0.72]
# ThumbUp [0.09 0.16 0.01 0.74]
# ThumbUp [0.38 0.11 0.02 0.49]
# ThumbUp [0.38 0.1  0.01 0.51]
# ThumbUp [0.38 0.11 0.01 0.5 ]
# ThumbUp [0.38 0.11 0.01 0.5 ]
# ThumbUp [0.38 0.11 0.01 0.5 ]
# ThumbUp [0.4  0.11 0.01 0.48]
# ThumbUp [0.4  0.11 0.01 0.48]
# Background [0.46 0.09 0.01 0.44]
# Background [0.56 0.06 0.01 0.37]
# Background [0.55 0.06 0.01 0.38]
# Background [0.54 0.06 0.02 0.38]
# Background [0.51 0.06 0.06 0.37]
# Background [0.43 0.05 0.19 0.33]
# Background [0.49 0.06 0.11 0.34]
# Background [0.43 0.06 0.15 0.36]
# Background [0.41 0.06 0.21 0.32]
# Background [0.46 0.07 0.14 0.33]
# Background [0.38 0.06 0.22 0.34]
# Background [0.38 0.06 0.22 0.34]
# Background [0.4  0.06 0.2  0.34]
# Background [0.38 0.05 0.26 0.31]
# Smile [0.31 0.05 0.38 0.26]
# Background [0.34 0.04 0.29 0.33]
# Background [0.37 0.04 0.23 0.36]
# Background [0.36 0.04 0.26 0.34]
# Background [0.36 0.04 0.25 0.35]
# ThumbUp [0.27 0.06 0.13 0.54]
# ThumbUp [0.27 0.06 0.09 0.58]
# ThumbUp [0.22 0.05 0.22 0.51]
# ThumbUp [0.17 0.04 0.26 0.53]
# ThumbUp [0.12 0.1  0.18 0.6 ]
# ThumbUp [0.11 0.1  0.11 0.68]
# ThumbUp [0.1  0.11 0.12 0.67]
# ThumbUp [0.09 0.12 0.13 0.66]
# ThumbUp [0.08 0.12 0.13 0.67]
# ThumbUp [0.09 0.12 0.11 0.68]
# ThumbUp [0.06 0.13 0.19 0.62]
# ThumbUp [0.05 0.12 0.2  0.63]
# Smile [0.04 0.08 0.5  0.38]
# Smile [0.05 0.09 0.43 0.43]
# ThumbUp [0.05 0.09 0.4  0.46]
# ThumbUp [0.05 0.1  0.39 0.46]
# Smile [0.04 0.1  0.46 0.4 ]
# Smile [0.04 0.09 0.48 0.39]
# Smile [0.04 0.09 0.47 0.4 ]
# Smile [0.04 0.09 0.47 0.4 ]
# Smile [0.04 0.09 0.47 0.4 ]
# Smile [0.04 0.09 0.47 0.4 ]
# Smile [0.04 0.09 0.44 0.43]
# Smile [0.04 0.08 0.5  0.38]
# Smile [0.03 0.08 0.47 0.42]
# ThumbUp [0.07 0.13 0.13 0.67]
# ThumbUp [0.05 0.11 0.2  0.64]
# Smile [0.04 0.08 0.45 0.43]
# ThumbUp [0.06 0.1  0.34 0.5 ]
# ThumbUp [0.07 0.11 0.2  0.62]
# ThumbUp [0.07 0.09 0.08 0.76]
# ThumbUp [0.09 0.1  0.   0.81]
# ThumbUp [0.09 0.1  0.   0.81]
# ThumbUp [0.09 0.1  0.   0.81]
# ThumbUp [0.09 0.1  0.   0.81]
# ThumbUp [0.09 0.11 0.   0.8 ]
# ThumbUp [0.07 0.1  0.23 0.6 ]
# ThumbUp [0.04 0.08 0.43 0.45]
# Smile [0.03 0.04 0.55 0.38]
# Smile [0.03 0.07 0.47 0.43]
# Smile [0.02 0.04 0.63 0.31]
# Smile [0.02 0.04 0.63 0.31]
# Smile [0.02 0.04 0.61 0.33]
# Smile [0.03 0.04 0.56 0.37]
# Smile [0.02 0.04 0.64 0.3 ]
# Smile [0.02 0.03 0.67 0.28]
# Smile [0.03 0.07 0.47 0.43]
# Smile [0.03 0.07 0.49 0.41]
# Smile [0.03 0.07 0.51 0.39]
# Smile [0.03 0.07 0.51 0.39]
# ThumbUp [0.05 0.09 0.41 0.45]
# ThumbUp [0.05 0.08 0.42 0.45]
# ThumbUp [0.04 0.09 0.42 0.45]
# Smile [0.03 0.07 0.48 0.42]
# Smile [0.03 0.08 0.46 0.43]
# Smile [0.03 0.06 0.52 0.39]
# Smile [0.03 0.06 0.53 0.38]
# Smile [0.03 0.06 0.54 0.37]
# Smile [0.03 0.07 0.51 0.39]
# Smile [0.03 0.07 0.52 0.38]
# Smile [0.03 0.07 0.53 0.37]
# Smile [0.03 0.07 0.54 0.36]
# Smile [0.03 0.06 0.58 0.33]
# Smile [0.03 0.06 0.58 0.33]
# Smile [0.03 0.07 0.51 0.39]
# Smile [0.03 0.07 0.53 0.37]
# ThumbUp [0.05 0.1  0.4  0.45]
# ThumbUp [0.04 0.09 0.43 0.44]
# Smile [0.04 0.08 0.44 0.44]
# ThumbUp [0.04 0.11 0.37 0.48]
# ThumbUp [0.06 0.12 0.17 0.65]
# ThumbUp [0.09 0.1  0.01 0.8 ]
# ThumbUp [0.07 0.11 0.14 0.68]
# Smile [0.13 0.09 0.4  0.38]
# Smile [0.15 0.08 0.44 0.33]
# Smile [0.15 0.08 0.44 0.33]
# Smile [0.17 0.07 0.42 0.34]
# Smile [0.17 0.07 0.46 0.3 ]
# Smile [0.16 0.07 0.46 0.31]
# Smile [0.14 0.05 0.57 0.24]
# Smile [0.16 0.05 0.54 0.25]
# Smile [0.14 0.07 0.51 0.28]
# Smile [0.16 0.06 0.56 0.22]
# Smile [0.15 0.05 0.58 0.22]
# Smile [0.15 0.05 0.6  0.2 ]
# Smile [0.15 0.04 0.57 0.24]
# Smile [0.15 0.04 0.57 0.24]
# Smile [0.15 0.05 0.57 0.23]
# Smile [0.13 0.03 0.68 0.16]
# Smile [0.15 0.04 0.58 0.23]
# Smile [0.05 0.05 0.53 0.37]
# ThumbUp [0.07 0.05 0.34 0.54]
# ThumbUp [0.07 0.09 0.24 0.6 ]
# ThumbUp [0.07 0.09 0.18 0.66]
# ThumbUp [0.06 0.08 0.25 0.61]
# ThumbUp [0.08 0.1  0.13 0.69]
# ThumbUp [0.07 0.1  0.15 0.68]
# ThumbUp [0.08 0.11 0.15 0.66]
# ThumbUp [0.06 0.08 0.19 0.67]
# ThumbUp [0.08 0.08 0.14 0.7 ]
# ThumbUp [0.08 0.11 0.13 0.68]
# ThumbUp [0.09 0.19 0.08 0.64]
# ThumbUp [0.09 0.21 0.11 0.59]
# ThumbUp [0.09 0.2  0.09 0.62]
# ThumbUp [0.08 0.21 0.13 0.58]
# ThumbUp [0.08 0.2  0.1  0.62]
# ThumbUp [0.05 0.18 0.26 0.51]
# ThumbUp [0.05 0.19 0.22 0.54]
# ThumbUp [0.05 0.15 0.35 0.45]
# ThumbUp [0.04 0.17 0.34 0.45]
# ThumbUp [0.04 0.16 0.37 0.43]
# ThumbUp [0.05 0.18 0.32 0.45]
# ThumbUp [0.05 0.18 0.33 0.44]
# ThumbUp [0.05 0.18 0.33 0.44]
# Smile [0.03 0.17 0.4  0.4 ]
# ThumbUp [0.05 0.19 0.33 0.43]
# ThumbUp [0.05 0.19 0.33 0.43]
# ThumbUp [0.05 0.18 0.34 0.43]
# ThumbUp [0.06 0.19 0.32 0.43]
# ThumbUp [0.05 0.16 0.22 0.57]
# ThumbUp [0.08 0.11 0.1  0.71]
# ThumbUp [0.18 0.09 0.05 0.68]
# ThumbUp [0.33 0.1  0.08 0.49]
# ThumbUp [0.41 0.11 0.02 0.46]
# Background [0.44 0.11 0.02 0.43]
# Background [0.47 0.15 0.02 0.36]
# Background [0.43 0.13 0.12 0.32]
# Smile [0.3  0.09 0.41 0.2 ]
# Smile [0.29 0.06 0.51 0.14]
# Smile [0.3  0.09 0.43 0.18]
# Smile [0.28 0.09 0.42 0.21]
# Smile [0.24 0.07 0.48 0.21]
# Smile [0.22 0.07 0.53 0.18]
# Smile [0.22 0.07 0.54 0.17]
# Smile [0.24 0.08 0.5  0.18]
# Smile [0.24 0.09 0.48 0.19]
# Smile [0.23 0.12 0.4  0.25]
# Smile [0.28 0.15 0.3  0.27]
# ThumbUp [0.29 0.15 0.22 0.34]
# ThumbUp [0.36 0.19 0.06 0.39]
# ThumbUp [0.32 0.22 0.01 0.45]
# Background [0.41 0.19 0.   0.4 ]
# Background [0.44 0.17 0.06 0.33]
# Background [0.38 0.15 0.16 0.31]
# Background [0.38 0.16 0.08 0.38]
# ThumbUp [0.39 0.19 0.   0.42]
# Background [0.45 0.17 0.   0.38]
# Background [0.6  0.13 0.01 0.26]
# Background [0.65 0.11 0.01 0.23]
# Background [0.65 0.11 0.01 0.23]
# Background [0.64 0.1  0.01 0.25]
# Background [0.65 0.11 0.01 0.23]
# Background [0.63 0.11 0.01 0.25]
# Background [0.61 0.12 0.01 0.26]
# Background [0.67 0.11 0.01 0.21]
# Background [0.67 0.11 0.01 0.21]
# Background [0.62 0.13 0.01 0.24]
# Background [0.62 0.13 0.01 0.24]
# Background [0.62 0.13 0.01 0.24]
# Background [0.62 0.12 0.01 0.25]
# Background [0.66 0.11 0.01 0.22]
# Background [0.67 0.11 0.01 0.21]
# Background [0.67 0.11 0.01 0.21]
# Background [0.67 0.11 0.01 0.21]
# Background [0.66 0.11 0.01 0.22]
# Background [0.69 0.1  0.01 0.2 ]
# Background [0.5  0.12 0.05 0.33]
# Background [0.5 0.1 0.1 0.3]
# Background [0.49 0.09 0.11 0.31]
# Background [0.56 0.12 0.01 0.31]
# Background [0.68 0.1  0.01 0.21]
# Background [0.68 0.1  0.01 0.21]
# Background [0.7  0.1  0.01 0.19]
# Background [0.69 0.1  0.01 0.2 ]
# Background [0.7  0.1  0.01 0.19]
# Background [0.71 0.09 0.01 0.19]
# Background [0.7  0.09 0.03 0.18]
# Background [0.64 0.11 0.05 0.2 ]
# Background [0.64 0.12 0.03 0.21]
# Background [0.61 0.13 0.03 0.23]
# Background [0.59 0.14 0.03 0.24]
# Background [0.58 0.13 0.05 0.24]
# Background [0.54 0.14 0.09 0.23]
# Background [0.53 0.14 0.11 0.22]
# Background [0.5  0.13 0.13 0.24]
# Background [0.47 0.14 0.13 0.26]
# Background [0.46 0.15 0.11 0.28]
# Background [0.45 0.16 0.1  0.29]
# Background [0.44 0.15 0.11 0.3 ]
# Background [0.43 0.16 0.09 0.32]
# Background [0.43 0.16 0.09 0.32]
# Background [0.39 0.16 0.13 0.32]
# Background [0.39 0.15 0.13 0.33]
# Background [0.44 0.15 0.05 0.36]
# Background [0.42 0.13 0.13 0.32]
# Background [0.41 0.12 0.15 0.32]
# Background [0.42 0.12 0.14 0.32]
# Background [0.4  0.11 0.18 0.31]
# Background [0.35 0.09 0.27 0.29]
# Background [0.31 0.09 0.3  0.3 ]
# Smile [0.25 0.07 0.45 0.23]
# Smile [0.2  0.07 0.53 0.2 ]
# Smile [0.23 0.08 0.44 0.25]
# Smile [0.21 0.07 0.51 0.21]
# Smile [0.17 0.1  0.54 0.19]
# Smile [0.22 0.1  0.41 0.27]
# Smile [0.19 0.09 0.53 0.19]
# Smile [0.21 0.09 0.52 0.18]
# Smile [0.26 0.1  0.44 0.2 ]
# Smile [0.29 0.11 0.35 0.25]
# Background [0.31 0.12 0.28 0.29]
# Smile [0.27 0.12 0.35 0.26]
# Background [0.3  0.12 0.29 0.29]
# Smile [0.25 0.12 0.4  0.23]
# ThumbUp [0.29 0.14 0.24 0.33]
# ThumbUp [0.28 0.15 0.27 0.3 ]
# Smile [0.25 0.18 0.32 0.25]
# Smile [0.23 0.17 0.38 0.22]
# Background [0.34 0.17 0.2  0.29]
# Background [0.31 0.17 0.26 0.26]
# Background [0.33 0.17 0.18 0.32]
# Smile [0.29 0.15 0.31 0.25]
# Background [0.34 0.15 0.19 0.32]
# Smile [0.28 0.13 0.32 0.27]
# Background [0.3  0.12 0.29 0.29]
# ThumbUp [0.35 0.13 0.16 0.36]
# ThumbUp [0.3  0.15 0.23 0.32]
# Smile [0.26 0.12 0.33 0.29]
# ThumbUp [0.31 0.17 0.2  0.32]
# Background [0.34 0.21 0.14 0.31]
# Background [0.4  0.22 0.01 0.37]
# Background [0.38 0.2  0.1  0.32]
# ThumbUp [0.25 0.24 0.1  0.41]
# ThumbUp [0.2  0.23 0.17 0.4 ]
# Question [0.19 0.33 0.16 0.32]
# ThumbUp [0.21 0.36 0.01 0.42]
# ThumbUp [0.2  0.37 0.   0.43]
# ThumbUp [0.19 0.36 0.07 0.38]
# ThumbUp [0.19 0.37 0.   0.44]
# ThumbUp [0.19 0.36 0.   0.45]
# ThumbUp [0.18 0.35 0.05 0.42]
# ThumbUp [0.18 0.35 0.06 0.41]
# ThumbUp [0.18 0.36 0.03 0.43]
# ThumbUp [0.18 0.36 0.03 0.43]
# ThumbUp [0.18 0.37 0.   0.45]
# ThumbUp [0.18 0.38 0.   0.44]
# ThumbUp [0.16 0.41 0.   0.43]
# ThumbUp [0.05 0.3  0.   0.65]
# ThumbUp [0.05 0.27 0.   0.68]
# ThumbUp [0.19 0.37 0.   0.44]
# ThumbUp [0.18 0.38 0.   0.44]
# ThumbUp [0.19 0.38 0.   0.43]
# ThumbUp [0.19 0.38 0.   0.43]
# ThumbUp [0.18 0.38 0.   0.44]
# ThumbUp [0.18 0.38 0.   0.44]
# ThumbUp [0.18 0.36 0.   0.46]
# ThumbUp [0.18 0.35 0.02 0.45]
# ThumbUp [0.13 0.28 0.01 0.58]
# ThumbUp [0.11 0.3  0.   0.59]
# ThumbUp [0.13 0.29 0.   0.58]
# ThumbUp [0.13 0.28 0.   0.59]
# ThumbUp [0.17 0.3  0.   0.53]
# ThumbUp [0.2  0.34 0.   0.46]
# ThumbUp [0.21 0.31 0.   0.48]
# ThumbUp [0.22 0.32 0.   0.46]
# ThumbUp [0.19 0.3  0.   0.51]
# ThumbUp [0.12 0.28 0.   0.6 ]
# ThumbUp [0.11 0.26 0.02 0.61]
# ThumbUp [0.11 0.27 0.02 0.6 ]
# ThumbUp [0.11 0.27 0.02 0.6 ]
# ThumbUp [0.11 0.28 0.04 0.57]
# ThumbUp [0.1  0.27 0.04 0.59]
# ThumbUp [0.1  0.27 0.04 0.59]
# ThumbUp [0.1  0.28 0.02 0.6 ]
# ThumbUp [0.1  0.28 0.02 0.6 ]
# ThumbUp [0.1  0.27 0.02 0.61]
# ThumbUp [0.1  0.28 0.02 0.6 ]
# ThumbUp [0.1  0.26 0.02 0.62]
# ThumbUp [0.09 0.26 0.02 0.63]
# ThumbUp [0.09 0.27 0.   0.64]
# ThumbUp [0.1  0.27 0.   0.63]
# ThumbUp [0.09 0.27 0.   0.64]
# ThumbUp [0.08 0.27 0.   0.65]
# ThumbUp [0.08 0.28 0.   0.64]
# ThumbUp [0.08 0.28 0.   0.64]
# ThumbUp [0.12 0.32 0.01 0.55]
# ThumbUp [0.13 0.36 0.01 0.5 ]
# ThumbUp [0.12 0.35 0.08 0.45]
# ThumbUp [0.12 0.34 0.12 0.42]
# ThumbUp [0.14 0.35 0.11 0.4 ]
# Question [0.14 0.38 0.1  0.38]
# Question [0.15 0.42 0.06 0.37]
# Question [0.19 0.4  0.05 0.36]
# Background [0.32 0.31 0.05 0.32]
# ThumbUp [0.32 0.28 0.07 0.33]
# Background [0.37 0.28 0.01 0.34]
# Background [0.45 0.25 0.01 0.29]
# Background [0.39 0.28 0.01 0.32]
# Background [0.34 0.28 0.05 0.33]
# Background [0.38 0.29 0.01 0.32]
# Background [0.35 0.32 0.01 0.32]
# ThumbUp [0.29 0.3  0.1  0.31]
# Question [0.27 0.33 0.07 0.33]
# ThumbUp [0.32 0.32 0.01 0.35]
# ThumbUp [0.32 0.32 0.   0.36]
# ThumbUp [0.33 0.32 0.   0.35]
# ThumbUp [0.33 0.32 0.   0.35]
# ThumbUp [0.34 0.31 0.   0.35]
# ThumbUp [0.32 0.31 0.02 0.35]
# Background [0.43 0.27 0.   0.3 ]
# Background [0.38 0.27 0.01 0.34]
# Background [0.45 0.22 0.   0.33]
# ThumbUp [0.34 0.24 0.   0.42]
# ThumbUp [0.36 0.21 0.   0.43]
# Background [0.4  0.21 0.01 0.38]
# Background [0.54 0.22 0.01 0.23]
# Background [0.59 0.13 0.01 0.27]
# Background [0.55 0.13 0.01 0.31]
# Background [0.56 0.13 0.01 0.3 ]
# Background [0.56 0.11 0.09 0.24]
# Background [0.57 0.11 0.09 0.23]
# Background [0.54 0.09 0.16 0.21]
# Background [0.51 0.04 0.27 0.18]
# Background [0.52 0.04 0.32 0.12]
# Background [0.56 0.12 0.2  0.12]
# Background [0.6  0.13 0.14 0.13]
# Background [0.63 0.16 0.01 0.2 ]
# Background [0.39 0.25 0.   0.36]
# ThumbUp [0.23 0.21 0.   0.56]
# ThumbUp [0.18 0.22 0.07 0.53]
# ThumbUp [0.19 0.25 0.01 0.55]
# ThumbUp [0.22 0.24 0.01 0.53]
# ThumbUp [0.19 0.3  0.11 0.4 ]
# ThumbUp [0.21 0.33 0.12 0.34]
# Question [0.22 0.34 0.12 0.32]
# Question [0.21 0.35 0.11 0.33]
# Question [0.18 0.31 0.2  0.31]
# ThumbUp [0.27 0.27 0.14 0.32]
# Background [0.3  0.28 0.13 0.29]
# Background [0.31 0.27 0.17 0.25]
# Background [0.38 0.29 0.   0.33]
# Background [0.39 0.27 0.   0.34]
# Smile [0.25 0.22 0.31 0.22]
# Background [0.4  0.23 0.15 0.22]
# ...
# Background [0.54 0.08 0.   0.38]
# Background [0.53 0.13 0.   0.34]
# Background [0.52 0.14 0.   0.34]
# Background [0.57 0.12 0.   0.31]
# Background [0.58 0.12 0.   0.3 ]
# Background [0.54 0.13 0.   0.33]
# Background [0.54 0.13 0.   0.33]
# Background [0.5  0.16 0.   0.34]
# Background [0.5  0.16 0.   0.34]
# Background [0.49 0.16 0.   0.35]
# Background [0.49 0.16 0.   0.35]
# Background [0.51 0.15 0.   0.34]
# Background [0.51 0.15 0.   0.34]
# Background [0.51 0.14 0.   0.35]
# Background [0.5  0.16 0.   0.34]
# Background [0.48 0.16 0.   0.36]
# Background [0.48 0.16 0.   0.36]
# Background [0.51 0.15 0.   0.34]
# Background [0.51 0.15 0.   0.34]
# Background [0.51 0.15 0.   0.34]
# Background [0.49 0.16 0.   0.35]
# Background [0.44 0.18 0.   0.38]
# Background [0.44 0.18 0.   0.38]
# Background [0.47 0.17 0.   0.36]
# Background [0.49 0.15 0.   0.36]
# Background [0.59 0.13 0.   0.28]
# Background [0.49 0.15 0.   0.36]
# Background [0.52 0.12 0.05 0.31]
# Background [0.56 0.11 0.   0.33]
# Background [0.52 0.12 0.01 0.35]
# Background [0.59 0.12 0.01 0.28]
# Background [0.57 0.12 0.   0.31]
# Background [0.61 0.11 0.01 0.27]
# Background [0.66 0.1  0.01 0.23]
# Background [0.67 0.08 0.01 0.24]
# Background [0.67 0.08 0.01 0.24]
# Background [0.67 0.08 0.01 0.24]
# Background [0.67 0.08 0.01 0.24]
# Background [0.61 0.08 0.   0.31]
# Background [0.64 0.09 0.01 0.26]
# Background [0.59 0.1  0.   0.31]
# Background [0.69 0.09 0.01 0.21]
# Background [0.58 0.1  0.01 0.31]
# Background [0.68 0.08 0.01 0.23]
# Background [0.68 0.08 0.01 0.23]
# Background [0.68 0.06 0.01 0.25]
# Background [0.69 0.08 0.01 0.22]
# Background [0.69 0.08 0.01 0.22]
# Background [0.69 0.08 0.02 0.21]
# Background [0.68 0.08 0.01 0.23]
# Background [0.68 0.08 0.01 0.23]
# Background [0.68 0.09 0.01 0.22]
# Background [0.65 0.09 0.01 0.25]
# Background [0.65 0.09 0.01 0.25]
# Background [0.65 0.09 0.01 0.25]
# Background [0.62 0.1  0.   0.28]
# Background [0.65 0.08 0.02 0.25]
# Background [0.65 0.1  0.01 0.24]
# Background [0.65 0.09 0.01 0.25]
# Background [0.65 0.09 0.01 0.25]
# Background [0.68 0.09 0.01 0.22]
# Background [0.59 0.07 0.   0.34]
# Background [0.59 0.08 0.   0.33]
# Background [0.68 0.07 0.01 0.24]
# Background [0.69 0.08 0.01 0.22]
# Background [0.69 0.08 0.01 0.22]
# Background [0.69 0.08 0.01 0.22]
# Background [0.65 0.1  0.01 0.24]
# Background [0.65 0.1  0.01 0.24]
# Background [0.66 0.07 0.01 0.26]
# Background [0.69 0.07 0.01 0.23]
# Background [0.69 0.07 0.01 0.23]
# Background [0.69 0.08 0.01 0.22]
# Background [0.66 0.07 0.05 0.22]
# Background [0.66 0.07 0.05 0.22]
# Background [0.59 0.07 0.15 0.19]
# Background [0.64 0.07 0.08 0.21]
# Background [0.43 0.04 0.35 0.18]
# Background [0.54 0.05 0.23 0.18]
# Background [0.7  0.07 0.01 0.22]
# Background [0.44 0.05 0.34 0.17]
# Background [0.43 0.05 0.35 0.17]
# Background [0.69 0.07 0.03 0.21]
# Background [0.71 0.08 0.01 0.2 ]
# Background [0.7  0.08 0.01 0.21]
# Background [0.74 0.07 0.01 0.18]
# Background [0.75 0.07 0.01 0.17]
# Background [0.75 0.06 0.01 0.18]
# Background [0.65 0.07 0.08 0.2 ]
# Background [0.62 0.08 0.11 0.19]
# Background [0.63 0.09 0.08 0.2 ]
# Background [0.39 0.06 0.35 0.2 ]
# Background [0.52 0.08 0.2  0.2 ]
# Smile [0.32 0.07 0.41 0.2 ]
# Background [0.4  0.07 0.34 0.19]
# Background [0.54 0.08 0.2  0.18]
# Background [0.47 0.08 0.25 0.2 ]
# Smile [0.32 0.07 0.43 0.18]
# Smile [0.36 0.06 0.43 0.15]
# Background [0.48 0.04 0.37 0.11]
# Background [0.57 0.04 0.28 0.11]
# Background [0.56 0.04 0.29 0.11]
# Background [0.49 0.04 0.36 0.11]
# Background [0.43 0.03 0.43 0.11]
# Smile [0.41 0.04 0.45 0.1 ]
# Smile [0.37 0.04 0.49 0.1 ]
# Smile [0.4  0.03 0.47 0.1 ]
# Background [0.46 0.03 0.4  0.11]
# Background [0.56 0.04 0.29 0.11]
# Smile [0.41 0.04 0.43 0.12]
# Smile [0.42 0.04 0.43 0.11]
# Background [0.44 0.03 0.43 0.1 ]
# Smile [0.38 0.04 0.49 0.09]
# Smile [0.4  0.04 0.47 0.09]
# Background [0.62 0.05 0.21 0.12]
# Background [0.78 0.06 0.01 0.15]
# Background [0.79 0.06 0.01 0.14]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.75 0.07 0.01 0.17]
# Background [0.75 0.07 0.01 0.17]
# Background [0.76 0.07 0.01 0.16]
# Background [0.75 0.07 0.01 0.17]
# Background [0.76 0.06 0.01 0.17]
# Background [0.75 0.07 0.01 0.17]
# Background [0.75 0.07 0.01 0.17]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.82 0.05 0.01 0.12]
# Background [0.79 0.06 0.01 0.14]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.81 0.05 0.01 0.13]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.75 0.07 0.01 0.17]
# Background [0.78 0.06 0.01 0.15]
# Background [0.79 0.06 0.01 0.14]
# Background [0.78 0.06 0.01 0.15]
# Background [0.78 0.06 0.01 0.15]
# Background [0.78 0.06 0.01 0.15]
# Background [0.79 0.06 0.01 0.14]
# Background [0.82 0.05 0.01 0.12]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.79 0.05 0.01 0.15]
# Background [0.81 0.05 0.01 0.13]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.79 0.06 0.01 0.14]
# Background [0.82 0.05 0.01 0.12]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.82 0.05 0.01 0.12]
# Background [0.8  0.05 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.8  0.05 0.01 0.14]
# Background [0.8  0.05 0.01 0.14]
# Background [0.8  0.05 0.01 0.14]
# Background [0.79 0.06 0.01 0.14]
# Background [0.78 0.06 0.01 0.15]
# Background [0.7  0.07 0.01 0.22]
# Background [0.71 0.06 0.02 0.21]
# Background [0.73 0.06 0.02 0.19]
# Background [0.68 0.06 0.09 0.17]
# Background [0.62 0.05 0.16 0.17]
# Background [0.5  0.08 0.15 0.27]
# Background [0.42 0.05 0.32 0.21]
# Background [0.43 0.05 0.37 0.15]
# Background [0.44 0.05 0.36 0.15]
# Smile [0.4  0.05 0.41 0.14]
# Smile [0.39 0.05 0.42 0.14]
# Background [0.64 0.05 0.16 0.15]
# Background [0.66 0.05 0.13 0.16]
# Background [0.68 0.07 0.08 0.17]
# Background [0.63 0.07 0.13 0.17]
# Background [0.59 0.06 0.18 0.17]
# Background [0.56 0.07 0.21 0.16]
# Smile [0.22 0.02 0.65 0.11]
# Background [0.51 0.08 0.18 0.23]
# Smile [0.18 0.02 0.7  0.1 ]
# Smile [0.25 0.03 0.61 0.11]
# Smile [0.14 0.02 0.74 0.1 ]
# Smile [0.12 0.02 0.76 0.1 ]
# Smile [0.03 0.   0.89 0.08]
# Smile [0.09 0.01 0.83 0.07]
# Background [0.53 0.05 0.19 0.23]
# Background [0.41 0.05 0.35 0.19]
# Smile [0.26 0.03 0.57 0.14]
# Background [0.54 0.05 0.18 0.23]
# Background [0.42 0.05 0.33 0.2 ]
# Background [0.54 0.05 0.18 0.23]
# Background [0.63 0.07 0.08 0.22]
# Background [0.59 0.06 0.12 0.23]
# Background [0.44 0.06 0.27 0.23]
# Background [0.59 0.08 0.11 0.22]
# Background [0.66 0.07 0.02 0.25]
# Background [0.63 0.08 0.06 0.23]
# Background [0.64 0.07 0.07 0.22]
# Background [0.69 0.07 0.02 0.22]
# Background [0.63 0.07 0.08 0.22]
# Background [0.68 0.07 0.02 0.23]
# Background [0.44 0.05 0.29 0.22]
# Background [0.56 0.05 0.16 0.23]
# Background [0.63 0.08 0.08 0.21]
# Background [0.63 0.07 0.08 0.22]
# Background [0.61 0.07 0.1  0.22]
# Background [0.61 0.07 0.11 0.21]
# Background [0.64 0.07 0.07 0.22]
# Background [0.64 0.08 0.06 0.22]
# Background [0.6  0.07 0.11 0.22]
# Background [0.58 0.06 0.13 0.23]
# Background [0.58 0.06 0.13 0.23]
# Background [0.59 0.07 0.11 0.23]
# Background [0.59 0.06 0.13 0.22]
# Background [0.58 0.07 0.12 0.23]
# Background [0.58 0.06 0.13 0.23]
# Background [0.59 0.06 0.13 0.22]
# Background [0.59 0.06 0.13 0.22]
# Smile [0.21 0.03 0.59 0.17]
# Background [0.49 0.05 0.24 0.22]
# Background [0.45 0.05 0.3  0.2 ]
# Background [0.53 0.05 0.2  0.22]
# Background [0.51 0.05 0.21 0.23]
# Background [0.43 0.04 0.34 0.19]
# Background [0.6  0.07 0.11 0.22]
# Background [0.45 0.06 0.31 0.18]
# Background [0.58 0.07 0.12 0.23]
# Background [0.45 0.05 0.29 0.21]
# Background [0.55 0.06 0.16 0.23]
# Background [0.53 0.05 0.19 0.23]
# Background [0.59 0.07 0.11 0.23]
# Background [0.58 0.07 0.12 0.23]
# Background [0.44 0.04 0.32 0.2 ]
# Background [0.49 0.05 0.24 0.22]
# Smile [0.32 0.03 0.48 0.17]
# Smile [0.31 0.03 0.49 0.17]
# Background [0.56 0.05 0.16 0.23]
# Background [0.57 0.07 0.13 0.23]
# Background [0.55 0.05 0.17 0.23]
# Background [0.45 0.05 0.31 0.19]
# Background [0.57 0.07 0.13 0.23]
# Background [0.55 0.05 0.17 0.23]
# Background [0.55 0.06 0.16 0.23]
# Background [0.6  0.07 0.08 0.25]
# Background [0.48 0.06 0.14 0.32]
# Background [0.51 0.08 0.1  0.31]
# Background [0.58 0.08 0.01 0.33]
# Background [0.59 0.07 0.01 0.33]
# Background [0.63 0.08 0.   0.29]
# Background [0.6  0.07 0.1  0.23]
# Background [0.63 0.09 0.06 0.22]
# Background [0.68 0.08 0.01 0.23]
# Background [0.67 0.08 0.01 0.24]
# Smile [0.34 0.03 0.45 0.18]
# Background [0.67 0.08 0.02 0.23]
# Background [0.67 0.09 0.01 0.23]
# Background [0.67 0.08 0.01 0.24]
# Background [0.67 0.09 0.01 0.23]
# Background [0.67 0.09 0.01 0.23]
# Background [0.67 0.09 0.01 0.23]
# Background [0.68 0.09 0.01 0.22]
# Background [0.69 0.08 0.01 0.22]
# Background [0.69 0.08 0.01 0.22]
# Background [0.7  0.07 0.01 0.22]
# Background [0.48 0.05 0.29 0.18]
# Background [0.44 0.09 0.2  0.27]
# Background [0.42 0.06 0.29 0.23]
# Background [0.59 0.07 0.13 0.21]
# Background [0.64 0.07 0.01 0.28]
# Background [0.7  0.07 0.01 0.22]
# Background [0.7  0.07 0.01 0.22]
# Background [0.7  0.06 0.03 0.21]
# Background [0.74 0.06 0.01 0.19]
# Background [0.69 0.08 0.01 0.22]
# Background [0.61 0.08 0.   0.31]
# Background [0.53 0.13 0.   0.34]
# Background [0.58 0.1  0.   0.32]
# Background [0.71 0.08 0.01 0.2 ]
# Background [0.74 0.07 0.01 0.18]
# Background [0.53 0.1  0.   0.37]
# Background [0.71 0.08 0.01 0.2 ]
# Background [0.69 0.08 0.01 0.22]
# Background [0.7  0.07 0.01 0.22]
# Background [0.6  0.07 0.08 0.25]
# Background [0.56 0.07 0.11 0.26]
# Background [0.58 0.08 0.12 0.22]
# Background [0.6  0.08 0.11 0.21]
# Background [0.57 0.08 0.14 0.21]
# Background [0.5  0.06 0.26 0.18]
# Background [0.54 0.07 0.21 0.18]
# Background [0.68 0.09 0.01 0.22]
# Background [0.38 0.08 0.35 0.19]
# Background [0.4  0.08 0.33 0.19]
# Background [0.41 0.07 0.33 0.19]
# Background [0.38 0.09 0.31 0.22]
# Background [0.45 0.06 0.28 0.21]
# Background [0.57 0.08 0.06 0.29]
# Background [0.61 0.08 0.   0.31]
# Background [0.61 0.08 0.   0.31]
# Background [0.61 0.08 0.   0.31]
# Background [0.56 0.1  0.   0.34]
# Background [0.55 0.1  0.   0.35]
# Background [0.57 0.09 0.   0.34]
# Background [0.58 0.09 0.   0.33]
# Background [0.59 0.09 0.   0.32]
# Background [0.58 0.09 0.   0.33]
# Background [0.55 0.1  0.   0.35]
# Background [0.59 0.09 0.   0.32]
# Background [0.6  0.09 0.   0.31]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.59 0.09 0.   0.32]
# Background [0.63 0.09 0.01 0.27]
# Background [0.69 0.09 0.01 0.21]
# Background [0.68 0.09 0.01 0.22]
# Background [0.67 0.09 0.01 0.23]
# Background [0.69 0.09 0.01 0.21]
# Background [0.68 0.09 0.01 0.22]
# Background [0.69 0.09 0.01 0.21]
# Background [0.69 0.09 0.01 0.21]
# Background [0.69 0.09 0.01 0.21]
# Background [0.69 0.09 0.01 0.21]
# Background [0.67 0.09 0.01 0.23]
# Background [0.67 0.09 0.01 0.23]
# Background [0.67 0.09 0.01 0.23]
# Background [0.67 0.09 0.01 0.23]
# Background [0.68 0.09 0.01 0.22]
# Background [0.68 0.09 0.01 0.22]
# Background [0.7  0.09 0.01 0.2 ]
# Background [0.7  0.09 0.01 0.2 ]
# Background [0.68 0.09 0.01 0.22]
# Background [0.68 0.09 0.01 0.22]
# Background [0.68 0.09 0.01 0.22]
# Background [0.67 0.08 0.01 0.24]
# Background [0.66 0.1  0.01 0.23]
# Background [0.5  0.06 0.26 0.18]
# Background [0.46 0.07 0.23 0.24]
# Background [0.41 0.06 0.33 0.2 ]
# Background [0.38 0.05 0.36 0.21]
# Smile [0.3  0.05 0.46 0.19]
# Smile [0.29 0.04 0.53 0.14]
# Smile [0.3  0.04 0.48 0.18]
# Smile [0.27 0.04 0.54 0.15]
# Smile [0.3  0.04 0.47 0.19]
# Smile [0.3  0.04 0.47 0.19]
# Smile [0.29 0.04 0.51 0.16]
# Smile [0.28 0.04 0.52 0.16]
# Smile [0.31 0.04 0.48 0.17]
# Smile [0.28 0.04 0.53 0.15]
# Smile [0.29 0.04 0.49 0.18]
# Smile [0.31 0.04 0.48 0.17]
# Smile [0.27 0.04 0.56 0.13]
# Smile [0.28 0.04 0.54 0.14]
# Smile [0.3  0.04 0.51 0.15]
# Smile [0.29 0.04 0.49 0.18]
# Smile [0.3  0.04 0.47 0.19]
# Smile [0.24 0.04 0.58 0.14]
# Smile [0.2  0.04 0.64 0.12]
# Smile [0.29 0.04 0.48 0.19]
# Smile [0.2  0.04 0.64 0.12]
# Smile [0.24 0.04 0.58 0.14]
# Smile [0.2  0.04 0.64 0.12]
# Smile [0.21 0.04 0.63 0.12]
# Smile [0.32 0.04 0.47 0.17]
# Smile [0.27 0.04 0.55 0.14]
# Smile [0.18 0.04 0.66 0.12]
# Smile [0.21 0.04 0.63 0.12]
# Smile [0.16 0.03 0.7  0.11]
# Smile [0.15 0.03 0.72 0.1 ]
# Smile [0.2  0.04 0.64 0.12]
# Smile [0.2  0.04 0.63 0.13]
# Smile [0.15 0.03 0.72 0.1 ]
# Smile [0.18 0.04 0.66 0.12]
# Smile [0.27 0.04 0.55 0.14]
# Smile [0.37 0.06 0.38 0.19]
# Smile [0.25 0.04 0.56 0.15]
# Smile [0.26 0.04 0.55 0.15]
# Smile [0.3  0.04 0.5  0.16]
# Smile [0.23 0.04 0.58 0.15]
# Smile [0.3  0.04 0.47 0.19]
# Smile [0.3  0.05 0.46 0.19]
# Smile [0.29 0.04 0.52 0.15]
# Smile [0.3  0.04 0.5  0.16]
# Background [0.57 0.08 0.05 0.3 ]
# Background [0.69 0.09 0.01 0.21]
# Background [0.66 0.09 0.01 0.24]
# Background [0.68 0.09 0.01 0.22]
# Background [0.7  0.09 0.01 0.2 ]
# Background [0.73 0.08 0.01 0.18]
# Background [0.73 0.08 0.01 0.18]
# Background [0.73 0.08 0.01 0.18]
# Background [0.73 0.08 0.01 0.18]
# Background [0.73 0.08 0.01 0.18]
# Background [0.73 0.1  0.01 0.16]
# Background [0.73 0.08 0.01 0.18]
# Background [0.71 0.09 0.01 0.19]
# Background [0.73 0.08 0.01 0.18]
# Background [0.73 0.08 0.01 0.18]
# Background [0.59 0.09 0.   0.32]
# Background [0.62 0.1  0.   0.28]
# Background [0.73 0.1  0.01 0.16]
# Background [0.73 0.1  0.01 0.16]
# Background [0.75 0.1  0.01 0.14]
# Background [0.56 0.14 0.   0.3 ]
# Background [0.54 0.09 0.07 0.3 ]
# Background [0.66 0.08 0.05 0.21]
# Smile [0.32 0.06 0.5  0.12]
# Background [0.71 0.08 0.01 0.2 ]
# Background [0.74 0.07 0.01 0.18]
# Background [0.78 0.08 0.01 0.13]
# Background [0.78 0.09 0.01 0.12]
# Background [0.79 0.08 0.01 0.12]
# Background [0.79 0.08 0.01 0.12]
# Background [0.78 0.09 0.01 0.12]
# Background [0.78 0.06 0.01 0.15]
# Background [0.78 0.06 0.01 0.15]
# Background [0.78 0.06 0.01 0.15]
# Background [0.78 0.06 0.01 0.15]
# Background [0.76 0.07 0.01 0.16]
# Background [0.78 0.05 0.01 0.16]
# Background [0.79 0.05 0.01 0.15]
# Background [0.79 0.05 0.01 0.15]
# Background [0.79 0.05 0.01 0.15]
# Background [0.78 0.05 0.01 0.16]
# Background [0.78 0.05 0.01 0.16]
# Background [0.78 0.05 0.01 0.16]
# Background [0.79 0.06 0.01 0.14]
# Background [0.77 0.06 0.01 0.16]
# Background [0.78 0.06 0.01 0.15]
# Background [0.81 0.05 0.01 0.13]
# Background [0.81 0.05 0.01 0.13]
# Background [0.81 0.05 0.01 0.13]
# Background [0.84 0.04 0.01 0.11]
# Background [0.86 0.03 0.01 0.1 ]
# Background [0.86 0.03 0.01 0.1 ]
# Background [0.87 0.03 0.01 0.09]
# Background [0.88 0.03 0.01 0.08]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.03 0.01 0.09]
# Background [0.87 0.02 0.01 0.1 ]
# Background [0.87 0.02 0.01 0.1 ]
# Background [0.88 0.02 0.01 0.09]
# Background [0.89 0.02 0.01 0.08]
# Background [0.9  0.02 0.01 0.07]
# Background [0.9  0.02 0.01 0.07]
# Background [0.9  0.01 0.01 0.08]
# Background [0.9  0.02 0.01 0.07]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (471, 269)

# %% [markdown]
# # Virtual Cam Test Demo

# %%
import pyvirtualcam
from pyvirtualcam import PixelFormat
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps_in = cap.get(cv2.CAP_PROP_FPS)
# cap = cv2.flip(originalCap, 1)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    with pyvirtualcam.Camera(width, height, fps_in, fmt=PixelFormat.BGR, print_fps=fps_in) as cam:
        print(f'Virtual cam started: {cam.device} ({cam.width}x{cam.height} @ {cam.fps}fps)')
    
        while cap.isOpened():
            ret, frame = cap.read()

            # Recolor Feed
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False        

            # Make Detections
            results = holistic.process(image)
            # print(results.face_landmarks)

            # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks

            # Recolor image back to BGR for rendering
            image.flags.writeable = True   
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 1. Draw face landmarks
            mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                     mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                     )

            # 2. Right hand
            mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                     )

            # 3. Left Hand
            mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                     )

            # 4. Pose Detections
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                     )
            # Export coordinates
            try:
                # Extract Pose landmarks
                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                # Extract Face landmarks
                face = results.face_landmarks.landmark
                face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

                # Concate rows
                row = pose_row+face_row

    #             # Append class name 
    #             row.insert(0, class_name)

    #             # Export to CSV
    #             with open('coords.csv', mode='a', newline='') as f:
    #                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    #                 csv_writer.writerow(row) 

                # Make Detections
                X = pd.DataFrame([row])
                body_language_class = model.predict(X)[0]
                body_language_prob = model.predict_proba(X)[0]
                print(body_language_class, body_language_prob)

                # Grab ear coords
                coords = tuple(np.multiply(
                                np.array(
                                    (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                     results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                            , [640,480]).astype(int))

                cv2.rectangle(image, 
                              (coords[0], coords[1]+5), 
                              (coords[0]+len(body_language_class)*20, coords[1]-30), 
                              (245, 117, 16), -1)
                cv2.putText(image, body_language_class, coords, 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

                # Get status box
                cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)

                # Display Class
                cv2.putText(image, 'CLASS'
                            , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
                cv2.putText(image, body_language_class.split(' ')[0]
                            , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

                # Display Probability
                cv2.putText(image, 'PROB'
                            , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
                cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                            , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            except:
                pass

            cv2.imshow('Raw Webcam Feed', image)
            cam.send(image)
            cam.sleep_until_next_frame()

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

cap.release()
cv2.destroyAllWindows()
# Out:
# Virtual cam started: OBS Virtual Camera (640x480 @ 30.0fps)
# Clap [0.04 0.49 0.   0.45 0.02]
# 30.0 fps
# Clap [0.03 0.49 0.   0.46 0.02]
# Clap [0.04 0.5  0.   0.44 0.02]
# Clap [0.02 0.5  0.   0.46 0.02]
# Clap [0.02 0.54 0.   0.42 0.02]
# Clap [0.01 0.6  0.   0.37 0.02]
# Clap [0.01 0.6  0.   0.36 0.03]
# Clap [0.01 0.55 0.   0.41 0.03]
# Clap [0.01 0.54 0.   0.42 0.03]
# 7.6 fps | 100 %
# Smile [0.01 0.48 0.   0.49 0.02]
# Smile [0.01 0.48 0.   0.49 0.02]
# Smile [0.01 0.45 0.   0.52 0.02]
# Smile [0.01 0.45 0.   0.52 0.02]
# Smile [0.01 0.44 0.   0.53 0.02]
# Smile [0.01 0.45 0.   0.51 0.03]
# Smile [0.01 0.45 0.   0.51 0.03]
# Smile [0.01 0.45 0.   0.51 0.03]
# 7.6 fps | 100 %
# Smile [0.01 0.47 0.   0.5  0.02]
# Clap [0.02 0.5  0.   0.46 0.02]
# Clap [0.1  0.59 0.   0.28 0.03]
# Clap [0.11 0.58 0.   0.28 0.03]
# Clap [0.11 0.58 0.   0.28 0.03]
# Clap [0.11 0.55 0.   0.31 0.03]
# Clap [0.1  0.56 0.   0.31 0.03]
# Clap [0.06 0.57 0.   0.35 0.02]
# 7.8 fps | 100 %
# Clap [0.03 0.59 0.   0.36 0.02]
# Clap [0.03 0.59 0.   0.35 0.03]
# Clap [0.02 0.52 0.   0.43 0.03]
# Smile [0.02 0.47 0.   0.48 0.03]
# Clap [0.01 0.49 0.   0.47 0.03]
# Clap [0.02 0.51 0.   0.44 0.03]
# Clap [0.03 0.58 0.   0.36 0.03]
# Clap [0.02 0.53 0.   0.42 0.03]
# 7.8 fps | 100 %
# Clap [0.02 0.5  0.   0.45 0.03]
# Smile [0.01 0.47 0.   0.49 0.03]
# Smile [0.01 0.47 0.   0.49 0.03]
# Smile [0.01 0.47 0.   0.49 0.03]
# Smile [0.01 0.47 0.   0.49 0.03]
# Smile [0.01 0.47 0.   0.49 0.03]
# Clap [0.01 0.48 0.   0.48 0.03]
# Clap [0.01 0.5  0.   0.46 0.03]
# 7.6 fps | 100 %
# Clap [0.02 0.5  0.   0.45 0.03]
# Clap [0.02 0.51 0.   0.44 0.03]
# Clap [0.02 0.5  0.   0.45 0.03]
# Clap [0.02 0.5  0.   0.45 0.03]
# Clap [0.01 0.48 0.   0.48 0.03]
# Clap [0.02 0.49 0.   0.46 0.03]
# Clap [0.02 0.5  0.   0.45 0.03]
# Clap [0.02 0.49 0.   0.46 0.03]
# 7.5 fps | 100 %
# Clap [0.02 0.51 0.   0.44 0.03]
# Clap [0.02 0.56 0.   0.39 0.03]
# Clap [0.02 0.56 0.   0.39 0.03]
# Clap [0.01 0.49 0.   0.47 0.03]
# Clap [0.03 0.6  0.   0.34 0.03]
# Clap [0.02 0.61 0.   0.34 0.03]
# Clap [0.03 0.57 0.   0.37 0.03]
# Clap [0.02 0.63 0.   0.33 0.02]
# 7.7 fps | 100 %
# Clap [0.03 0.62 0.   0.32 0.03]
# Clap [0.03 0.61 0.   0.33 0.03]
# Clap [0.03 0.61 0.   0.33 0.03]
# Clap [0.03 0.61 0.   0.33 0.03]
# Clap [0.03 0.62 0.   0.32 0.03]
# Clap [0.03 0.6  0.   0.34 0.03]
# Clap [0.03 0.59 0.   0.35 0.03]
# Clap [0.03 0.59 0.   0.35 0.03]
# 7.7 fps | 100 %
# Clap [0.03 0.61 0.   0.33 0.03]
# Clap [0.03 0.61 0.   0.33 0.03]
# Clap [0.03 0.59 0.   0.34 0.04]
# Clap [0.03 0.59 0.   0.35 0.03]
# Clap [0.03 0.59 0.   0.34 0.04]
# Clap [0.03 0.59 0.   0.34 0.04]
# Clap [0.03 0.48 0.   0.45 0.04]
# Smile [0.02 0.45 0.   0.49 0.04]
# 7.7 fps | 100 %
# Smile [0.02 0.44 0.   0.5  0.04]
# Smile [0.02 0.45 0.   0.49 0.04]
# Smile [0.01 0.46 0.   0.49 0.04]
# Clap [0.01 0.48 0.   0.46 0.05]
# Clap [0.01 0.49 0.   0.45 0.05]
# Smile [0.01 0.47 0.   0.48 0.04]
# Smile [0.01 0.47 0.   0.49 0.03]
# Smile [0.01 0.46 0.   0.5  0.03]
# 7.6 fps | 100 %
# Smile [0.01 0.47 0.   0.49 0.03]
# Smile [0.02 0.45 0.   0.5  0.03]
# Smile [0.02 0.45 0.   0.5  0.03]
# Smile [0.02 0.45 0.   0.5  0.03]
# Smile [0.02 0.42 0.   0.53 0.03]
# Smile [0.02 0.42 0.   0.53 0.03]
# Smile [0.02 0.42 0.   0.53 0.03]
# Smile [0.02 0.42 0.   0.53 0.03]
# 7.8 fps | 100 %
# Smile [0.02 0.42 0.   0.53 0.03]
# Smile [0.02 0.42 0.   0.53 0.03]
# Smile [0.02 0.43 0.   0.52 0.03]
# Smile [0.01 0.45 0.   0.51 0.03]
# Smile [0.01 0.44 0.   0.52 0.03]
# Smile [0.01 0.44 0.   0.52 0.03]
# Smile [0.01 0.45 0.   0.51 0.03]
# Smile [0.01 0.44 0.   0.52 0.03]
# 7.9 fps | 100 %
# Smile [0.01 0.44 0.   0.52 0.03]
# Smile [0.01 0.44 0.   0.52 0.03]
# Smile [0.01 0.45 0.   0.51 0.03]
# Smile [0.01 0.44 0.   0.52 0.03]
# Smile [0.01 0.43 0.   0.53 0.03]
# Smile [0.01 0.41 0.   0.55 0.03]
# Smile [0.01 0.42 0.   0.54 0.03]
# Smile [0.01 0.43 0.   0.53 0.03]
# 7.6 fps | 100 %
# Smile [0.01 0.42 0.   0.54 0.03]
# Smile [0.01 0.41 0.   0.55 0.03]
# Smile [0.01 0.41 0.   0.55 0.03]
# Smile [0.01 0.41 0.   0.55 0.03]
# Smile [0.01 0.41 0.   0.55 0.03]
# Smile [0.01 0.41 0.   0.55 0.03]
# Smile [0.   0.41 0.   0.56 0.03]
# Smile [0.   0.4  0.   0.57 0.03]
# 7.8 fps | 100 %
# Smile [0.   0.4  0.   0.57 0.03]
# Smile [0.   0.4  0.   0.57 0.03]
# Smile [0.   0.4  0.   0.58 0.02]
# Smile [0.   0.4  0.   0.58 0.02]
# Smile [0.01 0.39 0.   0.58 0.02]
# Smile [0.02 0.38 0.   0.58 0.02]
# Smile [0.05 0.46 0.   0.47 0.02]
# Clap [0.1  0.5  0.   0.38 0.02]
# 7.9 fps | 100 %
# Clap [0.11 0.5  0.   0.37 0.02]
# Clap [0.14 0.49 0.   0.35 0.02]
# Clap [0.15 0.47 0.   0.36 0.02]
# Clap [0.19 0.39 0.   0.39 0.03]
# Smile [0.23 0.3  0.   0.44 0.03]
# Smile [0.22 0.31 0.   0.43 0.04]
# Smile [0.21 0.35 0.   0.4  0.04]
# Clap [0.2  0.4  0.   0.37 0.03]
# 8.0 fps | 100 %
# Clap [0.19 0.4  0.   0.38 0.03]
# Clap [0.19 0.4  0.   0.38 0.03]
# Clap [0.19 0.42 0.   0.36 0.03]
# Clap [0.19 0.43 0.   0.35 0.03]
# Clap [0.19 0.41 0.   0.37 0.03]
# Clap [0.18 0.42 0.   0.37 0.03]
# Clap [0.18 0.43 0.   0.36 0.03]
# Clap [0.18 0.45 0.   0.34 0.03]
# 7.8 fps | 100 %
# Clap [0.18 0.44 0.   0.35 0.03]
# Smile [0.08 0.37 0.   0.53 0.02]
# Smile [0.06 0.29 0.   0.63 0.02]
# Smile [0.05 0.27 0.   0.66 0.02]
# Smile [0.05 0.31 0.   0.62 0.02]
# Smile [0.06 0.32 0.   0.6  0.02]
# Smile [0.05 0.29 0.   0.64 0.02]
# Smile [0.07 0.27 0.   0.63 0.03]
# 7.9 fps | 100 %
# Smile [0.08 0.42 0.   0.47 0.03]
# Clap [0.17 0.48 0.   0.32 0.03]
# Clap [0.16 0.48 0.   0.33 0.03]
# Clap [0.16 0.49 0.   0.32 0.03]
# Clap [0.16 0.48 0.   0.33 0.03]
# Clap [0.16 0.48 0.   0.33 0.03]
# Clap [0.16 0.48 0.   0.33 0.03]
# Clap [0.16 0.48 0.   0.33 0.03]
# 7.9 fps | 100 %
# Clap [0.16 0.48 0.   0.33 0.03]
# Clap [0.15 0.49 0.   0.33 0.03]
# Clap [0.13 0.42 0.   0.42 0.03]
# Smile [0.08 0.34 0.   0.56 0.02]
# Smile [0.08 0.3  0.   0.6  0.02]
# Smile [0.09 0.27 0.   0.62 0.02]
# Smile [0.07 0.26 0.   0.64 0.03]
# Smile [0.08 0.24 0.   0.65 0.03]
# 7.9 fps | 100 %
# Smile [0.07 0.27 0.   0.63 0.03]
# Clap [0.18 0.44 0.   0.34 0.04]
# Clap [0.17 0.47 0.   0.32 0.04]
# Clap [0.17 0.48 0.   0.32 0.03]
# Clap [0.18 0.48 0.   0.3  0.04]
# Clap [0.18 0.47 0.   0.31 0.04]
# Clap [0.13 0.55 0.   0.25 0.07]
# Clap [0.11 0.57 0.   0.24 0.08]
# 7.5 fps | 100 %
# Clap [0.11 0.57 0.   0.24 0.08]
# Clap [0.11 0.57 0.01 0.23 0.08]
# Clap [0.1  0.58 0.01 0.22 0.09]
# Clap [0.1  0.6  0.01 0.21 0.08]
# Clap [0.1  0.6  0.01 0.21 0.08]
# Clap [0.09 0.61 0.01 0.21 0.08]
# Clap [0.1  0.58 0.01 0.21 0.1 ]
# Clap [0.09 0.57 0.01 0.23 0.1 ]
# 7.4 fps | 100 %
# Clap [0.1  0.58 0.01 0.22 0.09]
# Clap [0.1  0.58 0.01 0.22 0.09]
# Clap [0.09 0.59 0.01 0.22 0.09]
# Clap [0.1  0.58 0.01 0.22 0.09]
# Clap [0.09 0.57 0.01 0.23 0.1 ]
# Clap [0.08 0.61 0.01 0.21 0.09]
# Clap [0.07 0.61 0.01 0.19 0.12]
# Clap [0.07 0.6  0.01 0.19 0.13]
# 7.7 fps | 100 %
# Clap [0.07 0.6  0.01 0.18 0.14]
# Clap [0.07 0.55 0.07 0.18 0.13]
# Clap [0.07 0.59 0.04 0.2  0.1 ]
# Clap [0.08 0.56 0.05 0.18 0.13]
# Clap [0.08 0.57 0.02 0.2  0.13]
# Clap [0.08 0.56 0.03 0.19 0.14]
# Clap [0.07 0.58 0.04 0.2  0.11]
# Clap [0.07 0.6  0.   0.19 0.14]
# 7.4 fps | 100 %
# Clap [0.05 0.6  0.01 0.18 0.16]
# Clap [0.06 0.51 0.   0.29 0.14]
# Clap [0.07 0.45 0.03 0.27 0.18]
# Clap [0.07 0.38 0.03 0.34 0.18]
# Clap [0.07 0.35 0.02 0.35 0.21]
# Smile [0.07 0.3  0.02 0.37 0.24]
# Smile [0.07 0.3  0.02 0.36 0.25]
# Smile [0.07 0.29 0.03 0.35 0.26]
# 7.6 fps | 100 %
# Smile [0.07 0.32 0.03 0.36 0.22]
# Smile [0.06 0.27 0.03 0.39 0.25]
# ThumbUp [0.07 0.28 0.03 0.3  0.32]
# Smile [0.06 0.31 0.03 0.35 0.25]
# Clap [0.06 0.37 0.03 0.37 0.17]
# Clap [0.07 0.36 0.03 0.35 0.19]
# Clap [0.06 0.34 0.02 0.3  0.28]
# Clap [0.05 0.35 0.02 0.29 0.29]
# 7.6 fps | 100 %
# Clap [0.07 0.36 0.01 0.34 0.22]
# Clap [0.07 0.38 0.01 0.35 0.19]
# Smile [0.06 0.33 0.01 0.37 0.23]
# Smile [0.05 0.31 0.01 0.4  0.23]
# Smile [0.05 0.32 0.01 0.4  0.22]
# Smile [0.05 0.32 0.01 0.4  0.22]
# Smile [0.07 0.33 0.01 0.37 0.22]
# Smile [0.06 0.33 0.01 0.38 0.22]
# 7.5 fps | 100 %
# Smile [0.07 0.34 0.01 0.37 0.21]
# Smile [0.07 0.35 0.   0.37 0.21]
# Clap [0.07 0.37 0.   0.35 0.21]
# Clap [0.07 0.37 0.   0.35 0.21]
# Clap [0.07 0.39 0.   0.35 0.19]
# Clap [0.06 0.39 0.   0.36 0.19]
# Clap [0.06 0.39 0.01 0.35 0.19]
# Clap [0.06 0.38 0.01 0.35 0.2 ]
# 7.4 fps | 100 %
# Clap [0.06 0.38 0.01 0.36 0.19]
# Clap [0.06 0.39 0.01 0.36 0.18]
# Clap [0.06 0.39 0.01 0.37 0.17]
# Clap [0.06 0.39 0.01 0.37 0.17]
# Clap [0.06 0.4  0.01 0.36 0.17]
# Clap [0.06 0.39 0.   0.38 0.17]
# Clap [0.06 0.38 0.03 0.37 0.16]
# Smile [0.05 0.35 0.07 0.38 0.15]
# 7.5 fps | 100 %
# Smile [0.05 0.37 0.07 0.38 0.13]
# Smile [0.05 0.37 0.06 0.39 0.13]
# Smile [0.05 0.36 0.06 0.4  0.13]
# Smile [0.05 0.37 0.06 0.39 0.13]
# Smile [0.05 0.36 0.06 0.4  0.13]
# Smile [0.04 0.34 0.06 0.43 0.13]
# Smile [0.06 0.35 0.06 0.4  0.13]
# Smile [0.07 0.35 0.06 0.39 0.13]
# 7.7 fps | 100 %
# Smile [0.07 0.35 0.06 0.39 0.13]
# Smile [0.07 0.36 0.06 0.4  0.11]
# Smile [0.08 0.36 0.06 0.39 0.11]
# Smile [0.08 0.36 0.06 0.4  0.1 ]
# Smile [0.08 0.35 0.06 0.39 0.12]
# Smile [0.08 0.34 0.06 0.39 0.13]
# Smile [0.08 0.36 0.06 0.39 0.11]
# Smile [0.08 0.36 0.06 0.39 0.11]
# 7.7 fps | 100 %
# Smile [0.08 0.35 0.06 0.4  0.11]
# Smile [0.08 0.34 0.06 0.41 0.11]
# Clap [0.05 0.37 0.08 0.23 0.27]
# ThumbUp [0.05 0.41 0.02 0.1  0.42]
# Clap [0.07 0.48 0.02 0.11 0.32]
# Clap [0.08 0.45 0.02 0.3  0.15]
# Clap [0.09 0.46 0.   0.4  0.05]
# Clap [0.08 0.51 0.   0.34 0.07]
# 7.5 fps | 100 %
# Clap [0.09 0.54 0.   0.31 0.06]
# Clap [0.08 0.54 0.   0.3  0.08]
# Clap [0.07 0.52 0.   0.34 0.07]
# Clap [0.05 0.56 0.   0.33 0.06]
# Clap [0.04 0.54 0.   0.35 0.07]
# Clap [0.04 0.55 0.   0.34 0.07]
# Clap [0.05 0.52 0.   0.36 0.07]
# Clap [0.05 0.49 0.   0.4  0.06]
# 7.7 fps | 100 %
# Clap [0.05 0.5  0.   0.39 0.06]
# Clap [0.04 0.56 0.   0.34 0.06]
# Clap [0.06 0.56 0.   0.31 0.07]
# Clap [0.05 0.56 0.   0.32 0.07]
# Clap [0.04 0.56 0.   0.34 0.06]
# Clap [0.04 0.54 0.   0.38 0.04]
# Clap [0.03 0.56 0.   0.4  0.01]
# Clap [0.04 0.56 0.   0.39 0.01]
# 7.6 fps | 100 %
# Clap [0.05 0.55 0.   0.39 0.01]
# Clap [0.05 0.54 0.   0.38 0.03]
# Clap [0.05 0.54 0.   0.38 0.03]
# Clap [0.05 0.53 0.   0.38 0.04]
# Clap [0.05 0.5  0.   0.39 0.06]
# Clap [0.05 0.51 0.   0.38 0.06]
# Clap [0.05 0.5  0.   0.39 0.06]
# Clap [0.05 0.5  0.   0.41 0.04]
# 7.3 fps | 100 %
# Clap [0.05 0.5  0.   0.39 0.06]
# Clap [0.05 0.49 0.   0.4  0.06]
# Clap [0.05 0.48 0.   0.42 0.05]
# Clap [0.05 0.48 0.   0.42 0.05]
# Clap [0.05 0.48 0.   0.42 0.05]
# Clap [0.05 0.48 0.   0.41 0.06]
# Clap [0.06 0.48 0.   0.41 0.05]
# Clap [0.09 0.47 0.   0.39 0.05]
# 7.5 fps | 100 %
# Clap [0.09 0.47 0.   0.39 0.05]
# Clap [0.14 0.47 0.   0.33 0.06]
# Clap [0.15 0.46 0.   0.32 0.07]
# Clap [0.16 0.51 0.   0.26 0.07]
# Clap [0.17 0.49 0.   0.27 0.07]
# Clap [0.17 0.49 0.   0.27 0.07]
# Clap [0.17 0.49 0.   0.28 0.06]
# Clap [0.17 0.48 0.   0.3  0.05]
# 7.8 fps | 100 %
# Background [0.53 0.21 0.02 0.01 0.23]
# Background [0.48 0.3  0.02 0.   0.2 ]
# Background [0.43 0.38 0.02 0.   0.17]
# Background [0.46 0.38 0.01 0.   0.15]
# Background [0.45 0.39 0.01 0.   0.15]
# Clap [0.38 0.39 0.01 0.01 0.21]
# Clap [0.28 0.39 0.   0.01 0.32]
# Clap [0.29 0.38 0.   0.01 0.32]
# 7.8 fps | 100 %
# Clap [0.25 0.37 0.   0.01 0.37]
# ThumbUp [0.24 0.36 0.   0.03 0.37]
# ThumbUp [0.26 0.33 0.   0.03 0.38]
# ThumbUp [0.27 0.31 0.   0.03 0.39]
# ThumbUp [0.17 0.28 0.01 0.01 0.53]
# ThumbUp [0.17 0.36 0.   0.01 0.46]
# ThumbUp [0.11 0.37 0.   0.   0.52]
# ThumbUp [0.1  0.38 0.01 0.   0.51]
# 7.7 fps | 100 %
# ThumbUp [0.1  0.37 0.01 0.   0.52]
# ThumbUp [0.09 0.37 0.01 0.   0.53]
# ThumbUp [0.12 0.4  0.   0.   0.48]
# ThumbUp [0.13 0.38 0.   0.   0.49]
# ThumbUp [0.16 0.35 0.01 0.   0.48]
# ThumbUp [0.16 0.35 0.01 0.   0.48]
# ThumbUp [0.16 0.35 0.01 0.   0.48]
# ThumbUp [0.16 0.35 0.01 0.   0.48]
# 7.7 fps | 100 %
# ThumbUp [0.18 0.36 0.01 0.01 0.44]
# ThumbUp [0.19 0.35 0.01 0.01 0.44]
# ThumbUp [0.19 0.35 0.01 0.01 0.44]
# ThumbUp [0.2  0.35 0.01 0.01 0.43]
# ThumbUp [0.26 0.31 0.01 0.03 0.39]
# ThumbUp [0.24 0.34 0.01 0.02 0.39]
# ThumbUp [0.26 0.32 0.01 0.03 0.38]
# ThumbUp [0.28 0.31 0.01 0.03 0.37]
# 7.7 fps | 100 %
# ThumbUp [0.22 0.35 0.01 0.02 0.4 ]
# ThumbUp [0.19 0.36 0.01 0.02 0.42]
# ThumbUp [0.17 0.36 0.01 0.01 0.45]
# ThumbUp [0.14 0.37 0.01 0.   0.48]
# ThumbUp [0.12 0.37 0.01 0.   0.5 ]
# ThumbUp [0.12 0.37 0.01 0.   0.5 ]
# ThumbUp [0.12 0.38 0.01 0.   0.49]
# ThumbUp [0.13 0.39 0.01 0.   0.47]
# 7.7 fps | 100 %
# ThumbUp [0.16 0.38 0.01 0.   0.45]
# ThumbUp [0.16 0.37 0.01 0.   0.46]
# ThumbUp [0.16 0.36 0.01 0.   0.47]
# ThumbUp [0.17 0.36 0.01 0.   0.46]
# ThumbUp [0.18 0.36 0.01 0.   0.45]
# ThumbUp [0.19 0.35 0.   0.01 0.45]
# ThumbUp [0.23 0.33 0.   0.01 0.43]
# ThumbUp [0.2  0.35 0.   0.01 0.44]
# 7.8 fps | 100 %
# ThumbUp [0.21 0.36 0.   0.01 0.42]
# ThumbUp [0.25 0.34 0.   0.03 0.38]
# ThumbUp [0.31 0.31 0.   0.05 0.33]
# ThumbUp [0.33 0.26 0.   0.05 0.36]
# Background [0.33 0.3  0.   0.04 0.33]
# Background [0.34 0.29 0.   0.03 0.34]
# ThumbUp [0.33 0.3  0.   0.03 0.34]
# Background [0.32 0.32 0.01 0.03 0.32]
# 7.7 fps | 100 %
# ThumbUp [0.32 0.31 0.01 0.03 0.33]
# Background [0.32 0.32 0.01 0.03 0.32]
# Background [0.33 0.31 0.01 0.03 0.32]
# Background [0.33 0.32 0.01 0.03 0.31]
# ThumbUp [0.3  0.32 0.01 0.03 0.34]
# ThumbUp [0.24 0.36 0.01 0.01 0.38]
# ThumbUp [0.22 0.36 0.01 0.01 0.4 ]
# ThumbUp [0.21 0.36 0.01 0.01 0.41]
# 7.8 fps | 100 %
# ThumbUp [0.2  0.37 0.01 0.   0.42]
# ThumbUp [0.2  0.38 0.01 0.   0.41]
# ThumbUp [0.2  0.38 0.01 0.   0.41]
# Clap [0.24 0.38 0.01 0.01 0.36]
# Clap [0.25 0.39 0.01 0.03 0.32]
# Clap [0.31 0.34 0.   0.03 0.32]
# Clap [0.3  0.39 0.   0.05 0.26]
# Clap [0.3  0.39 0.   0.05 0.26]
# 7.4 fps | 100 %
# Clap [0.32 0.37 0.   0.06 0.25]
# Clap [0.34 0.36 0.   0.06 0.24]
# Background [0.36 0.36 0.   0.06 0.22]
# Clap [0.35 0.36 0.   0.06 0.23]
# Clap [0.34 0.35 0.   0.06 0.25]
# Clap [0.34 0.35 0.   0.06 0.25]
# Clap [0.34 0.36 0.   0.06 0.24]
# Clap [0.34 0.36 0.   0.06 0.24]
# 7.8 fps | 100 %
# Clap [0.33 0.36 0.   0.06 0.25]
# Clap [0.33 0.37 0.   0.06 0.24]
# Clap [0.33 0.36 0.   0.06 0.25]
# Background [0.35 0.35 0.   0.05 0.25]
# Background [0.36 0.35 0.   0.05 0.24]
# Background [0.35 0.35 0.   0.05 0.25]
# Background [0.33 0.32 0.   0.06 0.29]
# Background [0.42 0.17 0.01 0.21 0.19]
# 7.7 fps | 100 %
# Smile [0.2  0.27 0.   0.48 0.05]
# Smile [0.21 0.33 0.   0.43 0.03]
# Clap [0.2  0.4  0.   0.37 0.03]
# Clap [0.18 0.43 0.   0.36 0.03]
# Clap [0.19 0.42 0.   0.36 0.03]
# Clap [0.18 0.43 0.   0.36 0.03]
# Clap [0.19 0.4  0.   0.36 0.05]
# Clap [0.18 0.43 0.   0.36 0.03]
# 7.8 fps | 100 %
# Clap [0.18 0.43 0.   0.36 0.03]
# Clap [0.18 0.41 0.   0.36 0.05]
# Smile [0.07 0.19 0.   0.71 0.03]
# Smile [0.08 0.21 0.   0.68 0.03]
# Smile [0.08 0.2  0.   0.69 0.03]
# Smile [0.08 0.2  0.   0.69 0.03]
# Smile [0.08 0.18 0.   0.71 0.03]
# Smile [0.08 0.2  0.   0.69 0.03]
# 7.7 fps | 100 %
# Smile [0.08 0.19 0.   0.7  0.03]
# Smile [0.14 0.32 0.   0.49 0.05]
# Smile [0.15 0.38 0.   0.41 0.06]
# Clap [0.12 0.42 0.   0.41 0.05]
# Clap [0.06 0.45 0.   0.44 0.05]
# Smile [0.05 0.42 0.   0.46 0.07]
# Clap [0.07 0.47 0.   0.36 0.1 ]
# Clap [0.07 0.45 0.   0.38 0.1 ]
# 7.7 fps | 100 %
# Clap [0.07 0.47 0.   0.35 0.11]
# Clap [0.09 0.42 0.   0.37 0.12]
# Clap [0.09 0.42 0.   0.36 0.13]
# Clap [0.12 0.41 0.01 0.3  0.16]
# Clap [0.12 0.4  0.01 0.3  0.17]
# Clap [0.1  0.4  0.01 0.28 0.21]
# Clap [0.1  0.41 0.   0.38 0.11]
# Smile [0.08 0.41 0.   0.42 0.09]
# 7.6 fps | 100 %
# Clap [0.08 0.43 0.   0.41 0.08]
# Smile [0.04 0.37 0.   0.53 0.06]
# Smile [0.04 0.39 0.   0.51 0.06]
# Smile [0.04 0.38 0.   0.51 0.07]
# Smile [0.04 0.37 0.   0.54 0.05]
# Smile [0.04 0.42 0.   0.5  0.04]
# Smile [0.05 0.42 0.   0.49 0.04]
# Smile [0.04 0.42 0.   0.48 0.06]
# 7.6 fps | 100 %
# Smile [0.04 0.42 0.   0.48 0.06]
# Smile [0.05 0.44 0.   0.46 0.05]
# Smile [0.04 0.41 0.   0.5  0.05]
# Smile [0.01 0.39 0.   0.55 0.05]
# Smile [0.01 0.37 0.   0.57 0.05]
# Smile [0.01 0.38 0.   0.56 0.05]
# Smile [0.02 0.4  0.   0.55 0.03]
# Smile [0.03 0.45 0.   0.5  0.02]
# 7.6 fps | 100 %
# Smile [0.04 0.46 0.   0.5  0.  ]
# Smile [0.04 0.46 0.   0.48 0.02]
# Clap [0.05 0.54 0.   0.39 0.02]
# Clap [0.08 0.52 0.   0.38 0.02]
# Clap [0.08 0.52 0.   0.38 0.02]
# Clap [0.08 0.51 0.   0.39 0.02]
# Clap [0.08 0.48 0.   0.42 0.02]
# Clap [0.07 0.49 0.   0.42 0.02]
# 7.7 fps | 100 %
# Clap [0.08 0.48 0.   0.42 0.02]
# Clap [0.08 0.48 0.   0.42 0.02]
# Clap [0.08 0.49 0.   0.41 0.02]
# Clap [0.08 0.49 0.   0.43 0.  ]
# Clap [0.09 0.52 0.   0.39 0.  ]
# Clap [0.07 0.48 0.   0.45 0.  ]
# Clap [0.08 0.49 0.   0.43 0.  ]
# Clap [0.08 0.5  0.   0.42 0.  ]
# 7.9 fps | 100 %
# Smile [0.07 0.46 0.   0.47 0.  ]
# Clap [0.09 0.51 0.   0.4  0.  ]
# Clap [0.09 0.51 0.   0.4  0.  ]
# Clap [0.07 0.47 0.   0.46 0.  ]
# Clap [0.07 0.49 0.   0.44 0.  ]
# Clap [0.07 0.48 0.   0.45 0.  ]
# Clap [0.07 0.49 0.   0.44 0.  ]
# Smile [0.07 0.46 0.   0.47 0.  ]
# 7.6 fps | 100 %
# Smile [0.07 0.45 0.   0.48 0.  ]
# Smile [0.05 0.43 0.   0.52 0.  ]
# Smile [0.05 0.43 0.   0.52 0.  ]
# Smile [0.07 0.44 0.   0.49 0.  ]
# Smile [0.07 0.46 0.   0.47 0.  ]
# Smile [0.07 0.46 0.   0.47 0.  ]
# Smile [0.04 0.4  0.   0.56 0.  ]
# Smile [0.05 0.4  0.   0.55 0.  ]
# 6.9 fps | 100 %
